# %% [markdown]
# <a href="https://colab.research.google.com/github/GianUOM/UniBath-Courseworks/blob/understandingdeeplearning/age_gender_submit_final_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Age Estimation and Gender Classification
#
# In this assignment, you will train CNN models to estimate a person's age and predict their gender based on face images. Please read carefully all the instructions before you start to write your code.
#
# **Your Tasks**
#
# You are supposed to train two CNN models.
# - Model A: Train a CNN model from scratch, following a few restrictions. Save this model as `age_gender_A.keras`
# - Model B: Fine-tune a pre-trained model to perform the same task. Save this model as `age_gender_B.keras`
#
# **Dataset**
#
# Your models will be trained and validated on a folder `train_val/` containing 5,000 labeled face images (size: 128 x 128), originated from the UTKFace dataset. During the assessment phase, your code will be tested on unseen test data.
#
# **Performance Metric**
#
# The evaluation of your models on the test set will be based on the following metrics:
# - age estimation: - Mean Absolute Error (MAE)
# - gender prediction: accuracy
#
# **GPU Time Management**
#
# Please use the available GPU time wisely, as there are some limitations on free GPU usage. It is said the users can use up to 12 hours in row in Google Colab. But many people found they reached its limit far less than 12 hours. To minimize the risk of reaching the limit, consider the following suggestions:
# 1. Ensure you have a stable internet connection.
# 2. Carefully validate your hyperparameters before starting the training process.
# 3. Based on past experience, each model should be trained in less than 2 hours. If the training time is significantly longer, you may need to adjust your model architecture.

# %% [markdown]
# ## Setting Up: Mount the google drive
# Mount your google drive to the notebook. Also don't forget to **enable GPU** before your training.

# %%
#
from google.colab import drive
drive.mount('/content/drive')
#
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Visualize a few photos
# It's always beneficial to thoroughly understand your data before beginning the training process. To get a first-hand impression of the dataset, please display a minimum of 20 images from the `train_val/` folder, along with their corresponding age and gender labels. This will help you gain initial insights into the dataset.

# %%
#
import os
import random
import cv2
import matplotlib.pyplot as plt

folder_train_val = "/content/drive/MyDrive/Colab Notebooks/DeepLearningAssignment/train_val"
# folder_train_val = "/Users/gianlucaaquilina/Downloads/train_val"
all_image_files = [file for file in os.listdir(folder_train_val) if file.lower().endswith(('.jpg'))]

random.seed(42)
sample_images = random.sample(all_image_files, min(20, len(all_image_files)))

plt.figure(figsize=(15, 10))

for i, image_file in enumerate(sample_images, 1):
    img_path = os.path.join(folder_train_val, image_file)
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    labels = image_file.split('_')
    age_label = int(labels[0])
    gender_label = "Male" if labels[1] == "0" else "Female"

    plt.subplot(4, 5, i)
    plt.imshow(img)
    plt.title(f"Age: {age_label}\nGender: {gender_label}")
    plt.axis('off')

plt.tight_layout()
plt.show()
#

# %% [markdown]
# ## Step 1: Data Pre-Processing
# In this step, you will perform necessary pre-processing tasks before feeding the data into a CNN. The pre-processing includes:
#
# 1. Splitting the data into training and validation sets.
# 2. Loading image data, gender labels and age values, and rescaling pixel values (originally integers between 0 and 255) to the range [0, 1].
# 3. Data augmentation
#
# The first two pre-processing steps have already been completed for you. Your task in this step is limited to:
#
# 3. Data augmentation
#
# Please note:
#
# - Do not modify any part of the provided code except the section marked with ########.
# - Do not rescale the age values to the range [0,1], as the original values are used during the testing stage. Rescaling them would significantly impact testing performance.

# %%
import os
import random
import numpy as np
from tensorflow.keras import layers, Sequential

folder_train_val = "/content/drive/MyDrive/Colab Notebooks/DeepLearningAssignment/train_val"
# folder_train_val = "/Users/gianlucaaquilina/Downloads/train_val"
all_image_files = [file for file in os.listdir(folder_train_val) if file.lower().endswith(('.jpg'))]

# Shuffle the dataset to ensure random distribution
random.seed(0)  # Ensure reproducibility
random.shuffle(all_image_files)

# Calculate the number of images for each set
n_train_val = len(all_image_files)
train_end = int(n_train_val * 0.8)

# Split the dataset
train_image_files = all_image_files[:train_end]
val_image_files = all_image_files[train_end:]
print(f"Number of images for training: {len(train_image_files)}")
print(f"Number of images for validation: {len(val_image_files)}")

def load_imgs_lables(dataset_path,filenames):
  print('load all image data, age and gender labels...')
  images = []
  age_labels = []
  gender_labels = []
  for current_file_name in filenames:
    img = cv2.imread(os.path.join(dataset_path, current_file_name))
    img = img / 255.0  # Normalize pixel values
    labels = current_file_name.split('_')
    age_label = int(labels[0])
    gender_label = int(labels[1])
    age_labels.append(age_label)
    gender_labels.append(gender_label)
    images.append(img)

  # Convert to NumPy arrays
  images = np.array(images)
  age_labels = np.array(age_labels)
  gender_labels = np.array(gender_labels)
  return images, age_labels, gender_labels

# load data from the training set
train_images, train_age, train_gender = load_imgs_lables(folder_train_val,train_image_files)

# load data from the validation set
val_images, val_age, val_gender = load_imgs_lables(folder_train_val,val_image_files)

#
data_augmentation = Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.15),
    layers.RandomTranslation(0.1, 0.1),
    layers.RandomBrightness(0.2),
    layers.RandomContrast(0.2)
])
#
# Out:
# Number of images for training: 4000
# Number of images for validation: 1000
# load all image data, age and gender labels...
# load all image data, age and gender labels...

# %% [markdown]
# ## STEP2A: Build your own CNN network
# In this step, you will define your own CNN model for identifying gender and predicting age. Although there are two tasks, you only need to build one CNN model with two outputs. You may refer to online resources for solutions.
#
# Here are the key requirements and restrictions for your network:
# 1.	The input size must be 128 x 128 x 3, which means you **should not resize** the original images. This is because my test code relies on this particular input size. Any other size will cause problem in the testing stage.
# 2.  Please treat the gender classification as a binary problem, i.e., **the output layer for the gender branch has only 1 unit**, instead of 2. Although it is technically correct to treat gender classification as a multi-class problem with 2 classes, i.e., 2 units in the last layer, the test code only supports a 1-unit last-layer configuration for the gender branch.
# 3.	The size of feature maps being fed to the first fully connected layer must be less than 10 x 10, while there is no number limitation about the depth.
# 4.	Incorporate techniques to prevent overfitting as appropriate.
#
# At the end of your implementation, use `modelA.summary()` to display the model architecture and use `plot_model()` to visualize the architecture.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

input_img = Input(shape=(128, 128, 3))

x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2))(x)
flatten = Flatten()(x)

age_dense = Dense(256, kernel_regularizer=l2(0.01), activation='relu')(flatten)
age_dense = Dropout(0.3)(age_dense)
age_dense = Dense(256, kernel_regularizer=l2(0.01), activation='relu')(age_dense)
age_dense = Dropout(0.3)(age_dense)
age_output = Dense(1, activation='linear', name='age_output')(age_dense)

gender_dense = Dense(256, activation='relu')(flatten)
gender_dense = Dropout(0.35)(gender_dense)
gender_dense = Dense(128, activation='relu')(gender_dense)
gender_dense = Dropout(0.25)(gender_dense)
gender_output = Dense(1, activation='sigmoid', name='gender_output')(gender_dense)

# Model with two outputs
modelA = Model(inputs=input_img, outputs=[age_output, gender_output])

#

modelA.summary()
from tensorflow.keras.utils import plot_model
plot_model(modelA, show_shapes=True,dpi=100)
# Out:
# Model: "functional_12"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_22      │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        896 │ input_layer_22[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 64, 64,    │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 64, 64,    │     18,496 │ max_pooling2d_3[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 32, 32,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │     73,856 │ max_pooling2d_4[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 16, 16,    │          0 │ conv2d_2[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 16, 16,    │    295,168 │ max_pooling2d_5[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 8, 8, 256) │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 16384)     │          0 │ max_pooling2d_6[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 256)       │  4,194,560 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 256)       │  4,194,560 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_21          │ (None, 256)       │          0 │ dense_15[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 256)       │          0 │ dense_17[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 256)       │     65,792 │ dropout_21[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 128)       │     32,896 │ dropout_23[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 256)       │          0 │ dense_16[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 128)       │          0 │ dense_18[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_output (Dense)  │ (None, 1)         │        257 │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gender_output       │ (None, 1)         │        129 │ dropout_24[0][0]  │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,876,610 (33.86 MB)
#  Trainable params: 8,876,610 (33.86 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## STEP3A: Compile and train your model
# Compile and train your model here.
# Save your model by `modelA.save(your_model_folder+"age_gender_A.keras")` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Save the model with `save()`** to save the entire model (including a model's architecture, weights, and training configuration) as a `.keras` zip archive. Don't save it with `save_weights()`.

# %%
from tensorflow.keras.optimizers import Adam

modelA.compile(
    loss={'gender_output': 'binary_crossentropy', 'age_output': 'mse'},
    optimizer=Adam(),
    metrics={'gender_output': 'accuracy', 'age_output': 'mae'}
)

from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)

epochs = 30
history = modelA.fit(
    train_images,
    {'gender_output': train_gender, 'age_output': train_age},
    validation_data=(val_images, {'gender_output': val_gender, 'age_output': val_age}),
    batch_size=16,
    callbacks=[early_stopping],
    epochs=epochs
)

folder_models = '/content/drive/MyDrive/Colab Notebooks/DeepLearningAssignment/models/'
# folder_models = '/Users/gianlucaaquilina/Documents/DeepLearning/models/'
import os
if not os.path.exists(folder_models):
  os.mkdir(folder_models)

#
modelA.save(folder_models+'age_gender_A.keras')
# Out:
# Epoch 1/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - age_output_loss: 791.8262 - age_output_mae: 21.3270 - gender_output_accuracy: 0.5191 - gender_output_loss: 0.8077 - loss: 797.4254 - val_age_output_loss: 378.6834 - val_age_output_mae: 15.0147 - val_gender_output_accuracy: 0.5130 - val_gender_output_loss: 0.6927 - val_loss: 382.2401
# Epoch 2/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - age_output_loss: 410.5689 - age_output_mae: 15.6682 - gender_output_accuracy: 0.4996 - gender_output_loss: 0.6950 - loss: 414.4528 - val_age_output_loss: 375.8650 - val_age_output_mae: 14.4089 - val_gender_output_accuracy: 0.5130 - val_gender_output_loss: 0.6929 - val_loss: 378.5991
# Epoch 3/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - age_output_loss: 404.3689 - age_output_mae: 15.5429 - gender_output_accuracy: 0.5084 - gender_output_loss: 0.6937 - loss: 407.9624 - val_age_output_loss: 377.9825 - val_age_output_mae: 14.5070 - val_gender_output_accuracy: 0.5130 - val_gender_output_loss: 0.6930 - val_loss: 381.3372
# Epoch 4/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - age_output_loss: 395.6563 - age_output_mae: 15.2288 - gender_output_accuracy: 0.5339 - gender_output_loss: 0.6882 - loss: 399.8463 - val_age_output_loss: 309.8654 - val_age_output_mae: 13.3583 - val_gender_output_accuracy: 0.6480 - val_gender_output_loss: 0.6471 - val_loss: 314.0309
# Epoch 5/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - age_output_loss: 347.7974 - age_output_mae: 14.5040 - gender_output_accuracy: 0.6123 - gender_output_loss: 0.6715 - loss: 352.5352 - val_age_output_loss: 324.8542 - val_age_output_mae: 14.4813 - val_gender_output_accuracy: 0.6370 - val_gender_output_loss: 0.6668 - val_loss: 329.4511
# Epoch 6/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - age_output_loss: 277.9238 - age_output_mae: 13.1669 - gender_output_accuracy: 0.6337 - gender_output_loss: 0.6450 - loss: 283.5259 - val_age_output_loss: 240.0245 - val_age_output_mae: 12.2515 - val_gender_output_accuracy: 0.7570 - val_gender_output_loss: 0.5385 - val_loss: 245.7529
# Epoch 7/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - age_output_loss: 226.3625 - age_output_mae: 11.4642 - gender_output_accuracy: 0.6970 - gender_output_loss: 0.5782 - loss: 233.2407 - val_age_output_loss: 205.0785 - val_age_output_mae: 10.8028 - val_gender_output_accuracy: 0.7790 - val_gender_output_loss: 0.4895 - val_loss: 211.5620
# Epoch 8/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - age_output_loss: 200.0431 - age_output_mae: 10.6722 - gender_output_accuracy: 0.7118 - gender_output_loss: 0.5321 - loss: 207.6671 - val_age_output_loss: 184.4892 - val_age_output_mae: 10.0539 - val_gender_output_accuracy: 0.8010 - val_gender_output_loss: 0.4354 - val_loss: 191.9044
# Epoch 9/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - age_output_loss: 181.7095 - age_output_mae: 10.0522 - gender_output_accuracy: 0.7343 - gender_output_loss: 0.5071 - loss: 189.9220 - val_age_output_loss: 177.9241 - val_age_output_mae: 10.3335 - val_gender_output_accuracy: 0.7690 - val_gender_output_loss: 0.4597 - val_loss: 186.2725
# Epoch 10/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - age_output_loss: 162.8700 - age_output_mae: 9.5968 - gender_output_accuracy: 0.7521 - gender_output_loss: 0.4720 - loss: 171.8561 - val_age_output_loss: 161.3483 - val_age_output_mae: 9.5254 - val_gender_output_accuracy: 0.8130 - val_gender_output_loss: 0.4146 - val_loss: 170.5315
# Epoch 11/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - age_output_loss: 138.0586 - age_output_mae: 8.9285 - gender_output_accuracy: 0.7794 - gender_output_loss: 0.4358 - loss: 147.8101 - val_age_output_loss: 164.5779 - val_age_output_mae: 9.1816 - val_gender_output_accuracy: 0.8280 - val_gender_output_loss: 0.3892 - val_loss: 174.0139
# Epoch 12/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - age_output_loss: 122.9539 - age_output_mae: 8.2148 - gender_output_accuracy: 0.7753 - gender_output_loss: 0.4385 - loss: 133.3314 - val_age_output_loss: 152.6331 - val_age_output_mae: 9.0051 - val_gender_output_accuracy: 0.8240 - val_gender_output_loss: 0.3819 - val_loss: 162.6349
# Epoch 13/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - age_output_loss: 113.7460 - age_output_mae: 7.9616 - gender_output_accuracy: 0.7805 - gender_output_loss: 0.4314 - loss: 124.6825 - val_age_output_loss: 147.7579 - val_age_output_mae: 9.1294 - val_gender_output_accuracy: 0.8370 - val_gender_output_loss: 0.3648 - val_loss: 158.0618
# Epoch 14/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - age_output_loss: 98.4502 - age_output_mae: 7.4157 - gender_output_accuracy: 0.8018 - gender_output_loss: 0.3943 - loss: 109.8041 - val_age_output_loss: 136.9169 - val_age_output_mae: 8.4988 - val_gender_output_accuracy: 0.8410 - val_gender_output_loss: 0.3414 - val_loss: 147.2532
# Epoch 15/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - age_output_loss: 86.8193 - age_output_mae: 7.0083 - gender_output_accuracy: 0.8148 - gender_output_loss: 0.3746 - loss: 98.5658 - val_age_output_loss: 131.0557 - val_age_output_mae: 8.2242 - val_gender_output_accuracy: 0.8430 - val_gender_output_loss: 0.3411 - val_loss: 141.8997
# Epoch 16/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - age_output_loss: 78.6871 - age_output_mae: 6.6598 - gender_output_accuracy: 0.8079 - gender_output_loss: 0.3725 - loss: 90.7542 - val_age_output_loss: 136.8078 - val_age_output_mae: 8.4953 - val_gender_output_accuracy: 0.8330 - val_gender_output_loss: 0.3495 - val_loss: 147.7874
# Epoch 17/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - age_output_loss: 66.2067 - age_output_mae: 6.0548 - gender_output_accuracy: 0.8010 - gender_output_loss: 0.3847 - loss: 78.5803 - val_age_output_loss: 130.2855 - val_age_output_mae: 8.1327 - val_gender_output_accuracy: 0.8320 - val_gender_output_loss: 0.3362 - val_loss: 142.4194
# Epoch 18/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - age_output_loss: 63.2114 - age_output_mae: 5.9647 - gender_output_accuracy: 0.8139 - gender_output_loss: 0.3601 - loss: 75.7243 - val_age_output_loss: 129.9143 - val_age_output_mae: 8.1069 - val_gender_output_accuracy: 0.8390 - val_gender_output_loss: 0.3260 - val_loss: 141.5647
# Epoch 19/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - age_output_loss: 55.5382 - age_output_mae: 5.6602 - gender_output_accuracy: 0.8209 - gender_output_loss: 0.3496 - loss: 68.1809 - val_age_output_loss: 129.9931 - val_age_output_mae: 8.1041 - val_gender_output_accuracy: 0.8430 - val_gender_output_loss: 0.3305 - val_loss: 141.5593
# Epoch 20/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - age_output_loss: 62.5139 - age_output_mae: 5.8710 - gender_output_accuracy: 0.8245 - gender_output_loss: 0.3368 - loss: 75.1758 - val_age_output_loss: 126.5852 - val_age_output_mae: 8.1658 - val_gender_output_accuracy: 0.8250 - val_gender_output_loss: 0.3525 - val_loss: 137.7717
# Epoch 21/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - age_output_loss: 53.3186 - age_output_mae: 5.5345 - gender_output_accuracy: 0.8269 - gender_output_loss: 0.3280 - loss: 66.0320 - val_age_output_loss: 131.0663 - val_age_output_mae: 8.0359 - val_gender_output_accuracy: 0.8370 - val_gender_output_loss: 0.3346 - val_loss: 142.9288
# Epoch 22/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - age_output_loss: 50.8040 - age_output_mae: 5.3583 - gender_output_accuracy: 0.8563 - gender_output_loss: 0.3120 - loss: 63.6631 - val_age_output_loss: 128.4709 - val_age_output_mae: 8.3911 - val_gender_output_accuracy: 0.8480 - val_gender_output_loss: 0.3346 - val_loss: 140.3175
# Epoch 23/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - age_output_loss: 46.1166 - age_output_mae: 5.0937 - gender_output_accuracy: 0.8633 - gender_output_loss: 0.2963 - loss: 58.9506 - val_age_output_loss: 125.1961 - val_age_output_mae: 8.0745 - val_gender_output_accuracy: 0.8430 - val_gender_output_loss: 0.3358 - val_loss: 136.8627
# Epoch 24/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - age_output_loss: 43.0980 - age_output_mae: 4.9542 - gender_output_accuracy: 0.8794 - gender_output_loss: 0.2751 - loss: 55.8154 - val_age_output_loss: 128.1764 - val_age_output_mae: 8.0192 - val_gender_output_accuracy: 0.8370 - val_gender_output_loss: 0.3467 - val_loss: 140.4237
# Epoch 25/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - age_output_loss: 44.6955 - age_output_mae: 4.9312 - gender_output_accuracy: 0.8807 - gender_output_loss: 0.2632 - loss: 57.3853 - val_age_output_loss: 135.6902 - val_age_output_mae: 8.2360 - val_gender_output_accuracy: 0.8380 - val_gender_output_loss: 0.3620 - val_loss: 147.4800
# Epoch 26/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - age_output_loss: 45.6177 - age_output_mae: 4.9435 - gender_output_accuracy: 0.8811 - gender_output_loss: 0.2570 - loss: 58.1622 - val_age_output_loss: 132.2041 - val_age_output_mae: 8.4320 - val_gender_output_accuracy: 0.8390 - val_gender_output_loss: 0.3807 - val_loss: 143.1769
# Epoch 27/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - age_output_loss: 45.3341 - age_output_mae: 5.0059 - gender_output_accuracy: 0.8763 - gender_output_loss: 0.2617 - loss: 57.7721 - val_age_output_loss: 126.9239 - val_age_output_mae: 8.0034 - val_gender_output_accuracy: 0.8420 - val_gender_output_loss: 0.3754 - val_loss: 138.3123
# Epoch 28/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - age_output_loss: 37.6019 - age_output_mae: 4.6170 - gender_output_accuracy: 0.9058 - gender_output_loss: 0.2064 - loss: 49.7697 - val_age_output_loss: 124.0760 - val_age_output_mae: 7.9315 - val_gender_output_accuracy: 0.8560 - val_gender_output_loss: 0.4106 - val_loss: 135.7872
# Epoch 29/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - age_output_loss: 40.8411 - age_output_mae: 4.7507 - gender_output_accuracy: 0.9009 - gender_output_loss: 0.2035 - loss: 52.8521 - val_age_output_loss: 124.4576 - val_age_output_mae: 7.9076 - val_gender_output_accuracy: 0.8550 - val_gender_output_loss: 0.4179 - val_loss: 135.4359
# Epoch 30/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - age_output_loss: 38.1018 - age_output_mae: 4.5475 - gender_output_accuracy: 0.9050 - gender_output_loss: 0.2080 - loss: 49.9790 - val_age_output_loss: 124.9586 - val_age_output_mae: 7.9435 - val_gender_output_accuracy: 0.8520 - val_gender_output_loss: 0.4551 - val_loss: 136.0991

# %% [markdown]
# ## STEP4A: Draw the learning curves
# Draw four learning curve figures for model A as follows.
# 1.	The loss of the gender classification over the training and validation set
# 2.	The accuracy of the gender classification over the training and validation set
# 3.	The loss of the age estimation over the training and validation set
# 4.	The MAE of the age estimation over the training and validation set

# %%
#
# Gender Classification Training and Validation Loss

plt.figure(figsize=(10,6))
plt.plot(history.history['gender_output_loss'], label='Training Loss')
plt.plot(history.history['val_gender_output_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.title('Gender Classification Training and Validation Loss')
plt.grid(True)
plt.ylim([0,1.0])
plt.legend()
plt.show()

# Gender Classification Training and Validation Accuracy

plt.figure(figsize=(10,6))
plt.plot(history.history['gender_output_accuracy'], label='Training Accuracy')
plt.plot(history.history['val_gender_output_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.title('Gender Classification Training and Validation Accuracy')
plt.grid(True)
plt.ylim([0,1.0])
plt.legend()
plt.show()

# Age Estimation Training and Validation Loss

plt.figure(figsize=(10,6))
plt.plot(history.history['age_output_loss'], label='Training Loss')
plt.plot(history.history['val_age_output_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.title('Age Estimation Training and Validation Loss')
plt.grid(True)
plt.legend()
plt.show()

# Age Estimation Training and Validation MAE

plt.figure(figsize=(10,6))
plt.plot(history.history['age_output_mae'], label='Mean Absolute Error (MAE) of Training Set')
plt.plot(history.history['val_age_output_mae'], label='Mean Absolute Error (MAE) of Validation Set')
plt.xlabel('Epoch')
plt.title('MAE of Age Estimation for Training and Validation Sets')
plt.grid(True)
plt.legend()
plt.show()
#

# %% [markdown]
# ## STEP2B: Build a CNN network based on a pre-trained model
# Choose an existing CNN architecture pre-trained on ImageNet and fine-tune it on this dataset.
#
# As with Model A, **do not resize the input image size**.
# Ensure that the output layer for **the gender branch has only 1 unit**.
#
# At the end of the cell, use `modelB.summary()` to display the model architecture and use `plot_model()` to visualize the architecture.

# %%
from tensorflow.keras.applications import MobileNetV2
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(128,128,3))

for layer in base_model.layers[:40]:
    layer.trainable = False


base_model.summary()
# Out:
# Model: "mobilenetv2_1.00_128"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_20      │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 64, 64,    │        864 │ input_layer_20[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 64, 64,    │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 64, 64,    │          0 │ bn_Conv1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │        288 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │        128 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 64, 64,    │        512 │ expanded_conv_de… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 64, 64,    │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 64, 64,    │      1,536 │ expanded_conv_pr… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 64, 64,    │        384 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 64, 64,    │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 65, 65,    │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 32, 32,    │        864 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 32, 32,    │        384 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 32, 32,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 32, 32,    │      2,304 │ block_1_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 32, 32,    │         96 │ block_1_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 32, 32,    │      3,456 │ block_1_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 32, 32,    │        576 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 32, 32,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 32, 32,    │      1,296 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 32, 32,    │        576 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 32, 32,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 32, 32,    │      3,456 │ block_2_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 32, 32,    │         96 │ block_2_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 32, 32,    │          0 │ block_1_project_… │
# │                     │ 24)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 32, 32,    │      3,456 │ block_2_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 32, 32,    │        576 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 32, 32,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 33, 33,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 16, 16,    │      1,296 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 16, 16,    │        576 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 16, 16,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 16, 16,    │      4,608 │ block_3_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 16, 16,    │        128 │ block_3_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 16, 16,    │      6,144 │ block_3_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 16, 16,    │        768 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 16, 16,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 16, 16,    │      1,728 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 16, 16,    │        768 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 16, 16,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 16, 16,    │      6,144 │ block_4_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 16, 16,    │        128 │ block_4_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 16, 16,    │          0 │ block_3_project_… │
# │                     │ 32)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 16, 16,    │      6,144 │ block_4_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 16, 16,    │        768 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 16, 16,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 16, 16,    │      1,728 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 16, 16,    │        768 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 16, 16,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 16, 16,    │      6,144 │ block_5_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 16, 16,    │        128 │ block_5_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 16, 16,    │          0 │ block_4_add[0][0… │
# │                     │ 32)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 16, 16,    │      6,144 │ block_5_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 16, 16,    │        768 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 16, 16,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 17, 17,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 8, 8, 192) │      1,728 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 8, 8, 192) │        768 │ block_6_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 8, 8, 192) │          0 │ block_6_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 8, 8, 64)  │     12,288 │ block_6_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 8, 8, 64)  │        256 │ block_6_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 8, 8, 384) │     24,576 │ block_6_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_7_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 8, 8, 384) │          0 │ block_7_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_7_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 8, 8, 384) │          0 │ block_7_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 8, 8, 64)  │     24,576 │ block_7_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 8, 8, 64)  │        256 │ block_7_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_6_project_… │
# │                     │                   │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 8, 8, 384) │     24,576 │ block_7_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_8_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 8, 8, 384) │          0 │ block_8_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_8_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 8, 8, 384) │          0 │ block_8_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 8, 8, 64)  │     24,576 │ block_8_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 8, 8, 64)  │        256 │ block_8_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_7_add[0][0… │
# │                     │                   │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 8, 8, 384) │     24,576 │ block_8_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_9_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 8, 8, 384) │          0 │ block_9_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_9_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 8, 8, 384) │          0 │ block_9_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 8, 8, 64)  │     24,576 │ block_9_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 8, 8, 64)  │        256 │ block_9_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_8_add[0][0… │
# │                     │                   │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 8, 8, 384) │     24,576 │ block_9_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 8, 8, 384) │      1,536 │ block_10_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 8, 8, 384) │          0 │ block_10_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 8, 8, 384) │      3,456 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 8, 8, 384) │      1,536 │ block_10_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 8, 8, 384) │          0 │ block_10_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 8, 8, 96)  │     36,864 │ block_10_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 8, 8, 96)  │        384 │ block_10_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 8, 8, 576) │     55,296 │ block_10_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_11_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 8, 8, 576) │          0 │ block_11_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 8, 8, 576) │      5,184 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 8, 8, 576) │      2,304 │ block_11_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 8, 8, 576) │          0 │ block_11_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 8, 8, 96)  │     55,296 │ block_11_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 8, 8, 96)  │        384 │ block_11_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 8, 8, 96)  │          0 │ block_10_project… │
# │                     │                   │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 8, 8, 576) │     55,296 │ block_11_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_12_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 8, 8, 576) │          0 │ block_12_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 8, 8, 576) │      5,184 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 8, 8, 576) │      2,304 │ block_12_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 8, 8, 576) │          0 │ block_12_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 8, 8, 96)  │     55,296 │ block_12_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 8, 8, 96)  │        384 │ block_12_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 8, 8, 96)  │          0 │ block_11_add[0][… │
# │                     │                   │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 8, 8, 576) │     55,296 │ block_12_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_13_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 8, 8, 576) │          0 │ block_13_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 9, 9, 576) │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 4, 4, 576) │      5,184 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 4, 4, 576) │      2,304 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 4, 4, 576) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 4, 4, 160) │     92,160 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 4, 4, 160) │        640 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 4, 4, 960) │    153,600 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 4, 4, 960) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 4, 4, 960) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 4, 4, 160) │    153,600 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 4, 4, 160) │        640 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 4, 4, 160) │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 4, 4, 960) │    153,600 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 4, 4, 960) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 4, 4, 960) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 4, 4, 160) │    153,600 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 4, 4, 160) │        640 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 4, 4, 160) │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 4, 4, 960) │    153,600 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 4, 4, 960) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 4, 4, 960) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 4, 4, 320) │    307,200 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 4, 4, 320) │      1,280 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 4, 4,      │    409,600 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 4, 4,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 4, 4,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,257,984 (8.61 MB)
#  Trainable params: 2,189,824 (8.35 MB)
#  Non-trainable params: 68,160 (266.25 KB)

# %%
inputs = Input(shape=(128, 128, 3))
x = data_augmentation(inputs)

x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)

# Gender branch
gender_x = layers.Dense(128, activation='relu')(x)
gender_x = layers.Dropout(0.3)(gender_x)
gender_output = layers.Dense(1, activation='sigmoid', name='gender_output')(gender_x)

# Age branch
age_x = layers.Dense(128, activation='relu')(x)
age_x = layers.Dropout(0.3)(age_x)
age_output = layers.Dense(1, activation='linear', name='age_output')(age_x)


modelB = Model(inputs=inputs, outputs=[gender_output, age_output])

#

modelB.summary()
from tensorflow.keras.utils import plot_model
plot_model(modelB, show_shapes=True,dpi=100)
# Out:
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_21      │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mobilenetv2_1.00_1… │ (None, 4, 4,      │  2,257,984 │ input_layer_21[0… │
# │ (Functional)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ mobilenetv2_1.00… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 1280)      │          0 │ global_average_p… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 128)       │    163,968 │ dropout_18[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 128)       │    163,968 │ dropout_18[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 128)       │          0 │ dense_13[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 128)       │          0 │ dense_14[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gender_output       │ (None, 1)         │        129 │ dropout_19[0][0]  │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_output (Dense)  │ (None, 1)         │        129 │ dropout_20[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,586,178 (9.87 MB)
#  Trainable params: 2,518,018 (9.61 MB)
#  Non-trainable params: 68,160 (266.25 KB)

# %% [markdown]
# ## STEP3B: Compile and train your model
# Compile and train your model here.
# Save your model to `age_gender_B.keras` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Also, save the model with `save()` instead of `save_weights()`.**

# %%
#
from tensorflow.keras.optimizers import SGD

modelB.compile(
    loss={'gender_output': 'binary_crossentropy', 'age_output': 'mse'},
    optimizer=SGD(learning_rate=1e-4, momentum=0.9),
    metrics={'gender_output': 'accuracy', 'age_output': 'mae'}
)

from tensorflow.keras.callbacks import EarlyStopping
es_callback = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True
)

epochs = 100
history = modelB.fit(
    train_images,
    {'gender_output': train_gender, 'age_output': train_age},
    validation_data=(val_images, {'gender_output': val_gender, 'age_output': val_age}),
    epochs=epochs,
    callbacks=[es_callback]
)

your_model_folder = '/content/drive/MyDrive/Colab Notebooks/DeepLearningAssignment/models/'
#your_model_folder = '/Users/gianlucaaquilina/Documents/DeepLearning/models/'
import os
if not os.path.exists(your_model_folder):
  os.mkdir(your_model_folder)
#

modelB.save(your_model_folder+"age_gender_B.keras")
# Out:
# Epoch 1/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 37s 100ms/step - age_output_loss: 471.8073 - age_output_mae: 15.8552 - gender_output_accuracy: 0.5210 - gender_output_loss: 0.7725 - loss: 472.5798 - val_age_output_loss: 3919.6733 - val_age_output_mae: 60.4897 - val_gender_output_accuracy: 0.4940 - val_gender_output_loss: 0.7841 - val_loss: 3930.3533
# Epoch 2/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - age_output_loss: 133.6286 - age_output_mae: 8.5338 - gender_output_accuracy: 0.5515 - gender_output_loss: 0.6965 - loss: 134.3251 - val_age_output_loss: 5261.8428 - val_age_output_mae: 70.8069 - val_gender_output_accuracy: 0.5010 - val_gender_output_loss: 0.7266 - val_loss: 5267.6567
# Epoch 3/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - age_output_loss: 99.7186 - age_output_mae: 7.3600 - gender_output_accuracy: 0.5739 - gender_output_loss: 0.6952 - loss: 100.4137 - val_age_output_loss: 4404.3013 - val_age_output_mae: 64.5590 - val_gender_output_accuracy: 0.5150 - val_gender_output_loss: 0.8160 - val_loss: 4412.5181
# Epoch 4/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 93.4703 - age_output_mae: 7.1866 - gender_output_accuracy: 0.5779 - gender_output_loss: 0.6905 - loss: 94.1608 - val_age_output_loss: 2813.9285 - val_age_output_mae: 50.8166 - val_gender_output_accuracy: 0.5120 - val_gender_output_loss: 0.7213 - val_loss: 2809.7178
# Epoch 5/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - age_output_loss: 69.8972 - age_output_mae: 6.2026 - gender_output_accuracy: 0.5915 - gender_output_loss: 0.6662 - loss: 70.5634 - val_age_output_loss: 3318.1282 - val_age_output_mae: 55.9691 - val_gender_output_accuracy: 0.5140 - val_gender_output_loss: 0.9502 - val_loss: 3324.0835
# Epoch 6/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 66.8949 - age_output_mae: 6.1061 - gender_output_accuracy: 0.6098 - gender_output_loss: 0.6648 - loss: 67.5597 - val_age_output_loss: 3557.1880 - val_age_output_mae: 57.9994 - val_gender_output_accuracy: 0.5130 - val_gender_output_loss: 1.2309 - val_loss: 3555.8105
# Epoch 7/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - age_output_loss: 58.8790 - age_output_mae: 5.6602 - gender_output_accuracy: 0.5900 - gender_output_loss: 0.6723 - loss: 59.5513 - val_age_output_loss: 2213.9761 - val_age_output_mae: 44.9314 - val_gender_output_accuracy: 0.5130 - val_gender_output_loss: 1.0248 - val_loss: 2221.5928
# Epoch 8/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 55.7165 - age_output_mae: 5.5227 - gender_output_accuracy: 0.6230 - gender_output_loss: 0.6530 - loss: 56.3695 - val_age_output_loss: 2418.5288 - val_age_output_mae: 47.5344 - val_gender_output_accuracy: 0.5260 - val_gender_output_loss: 0.8508 - val_loss: 2406.7776
# Epoch 9/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - age_output_loss: 58.9116 - age_output_mae: 5.6072 - gender_output_accuracy: 0.6290 - gender_output_loss: 0.6500 - loss: 59.5616 - val_age_output_loss: 1269.4044 - val_age_output_mae: 33.4661 - val_gender_output_accuracy: 0.5260 - val_gender_output_loss: 0.8626 - val_loss: 1260.3127
# Epoch 10/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 51.8827 - age_output_mae: 5.3473 - gender_output_accuracy: 0.6046 - gender_output_loss: 0.6606 - loss: 52.5433 - val_age_output_loss: 1333.3313 - val_age_output_mae: 34.3214 - val_gender_output_accuracy: 0.5230 - val_gender_output_loss: 0.8871 - val_loss: 1321.8835
# Epoch 11/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - age_output_loss: 49.8992 - age_output_mae: 5.2288 - gender_output_accuracy: 0.6306 - gender_output_loss: 0.6542 - loss: 50.5534 - val_age_output_loss: 2101.2498 - val_age_output_mae: 44.0020 - val_gender_output_accuracy: 0.5270 - val_gender_output_loss: 0.8284 - val_loss: 2091.5342
# Epoch 12/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 38.2193 - age_output_mae: 4.6274 - gender_output_accuracy: 0.6336 - gender_output_loss: 0.6400 - loss: 38.8593 - val_age_output_loss: 1326.8585 - val_age_output_mae: 34.4659 - val_gender_output_accuracy: 0.5290 - val_gender_output_loss: 0.8257 - val_loss: 1314.9275
# Epoch 13/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 35.6222 - age_output_mae: 4.4784 - gender_output_accuracy: 0.6443 - gender_output_loss: 0.6294 - loss: 36.2516 - val_age_output_loss: 1129.8667 - val_age_output_mae: 31.5542 - val_gender_output_accuracy: 0.5310 - val_gender_output_loss: 0.7698 - val_loss: 1121.2738
# Epoch 14/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - age_output_loss: 34.7129 - age_output_mae: 4.3528 - gender_output_accuracy: 0.6444 - gender_output_loss: 0.6351 - loss: 35.3480 - val_age_output_loss: 1524.6951 - val_age_output_mae: 37.1445 - val_gender_output_accuracy: 0.5310 - val_gender_output_loss: 0.7545 - val_loss: 1516.4740
# Epoch 15/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - age_output_loss: 31.7679 - age_output_mae: 4.1779 - gender_output_accuracy: 0.6549 - gender_output_loss: 0.6363 - loss: 32.4042 - val_age_output_loss: 1199.0848 - val_age_output_mae: 32.4147 - val_gender_output_accuracy: 0.5240 - val_gender_output_loss: 0.7827 - val_loss: 1193.6973
# Epoch 16/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 29.1760 - age_output_mae: 3.9164 - gender_output_accuracy: 0.6419 - gender_output_loss: 0.6324 - loss: 29.8083 - val_age_output_loss: 1406.1763 - val_age_output_mae: 35.3475 - val_gender_output_accuracy: 0.5300 - val_gender_output_loss: 0.8415 - val_loss: 1393.7371
# Epoch 17/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 31.1540 - age_output_mae: 4.1104 - gender_output_accuracy: 0.6392 - gender_output_loss: 0.6405 - loss: 31.7945 - val_age_output_loss: 424.4680 - val_age_output_mae: 18.1855 - val_gender_output_accuracy: 0.5830 - val_gender_output_loss: 0.6989 - val_loss: 417.8437
# Epoch 18/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - age_output_loss: 28.3623 - age_output_mae: 3.9635 - gender_output_accuracy: 0.6535 - gender_output_loss: 0.6272 - loss: 28.9895 - val_age_output_loss: 895.5613 - val_age_output_mae: 27.6834 - val_gender_output_accuracy: 0.5620 - val_gender_output_loss: 0.6994 - val_loss: 888.1189
# Epoch 19/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 29.4869 - age_output_mae: 3.9814 - gender_output_accuracy: 0.6638 - gender_output_loss: 0.6212 - loss: 30.1082 - val_age_output_loss: 484.9425 - val_age_output_mae: 19.6563 - val_gender_output_accuracy: 0.5770 - val_gender_output_loss: 0.6755 - val_loss: 478.1923
# Epoch 20/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - age_output_loss: 25.2763 - age_output_mae: 3.7378 - gender_output_accuracy: 0.6659 - gender_output_loss: 0.6226 - loss: 25.8989 - val_age_output_loss: 456.5444 - val_age_output_mae: 19.2523 - val_gender_output_accuracy: 0.5650 - val_gender_output_loss: 0.6849 - val_loss: 455.5241
# Epoch 21/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 25.8543 - age_output_mae: 3.6403 - gender_output_accuracy: 0.6602 - gender_output_loss: 0.6226 - loss: 26.4769 - val_age_output_loss: 397.0538 - val_age_output_mae: 17.4186 - val_gender_output_accuracy: 0.6040 - val_gender_output_loss: 0.6463 - val_loss: 394.2519
# Epoch 22/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - age_output_loss: 22.4371 - age_output_mae: 3.5346 - gender_output_accuracy: 0.6580 - gender_output_loss: 0.6243 - loss: 23.0614 - val_age_output_loss: 400.4727 - val_age_output_mae: 17.3887 - val_gender_output_accuracy: 0.6000 - val_gender_output_loss: 0.6642 - val_loss: 394.8896
# Epoch 23/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 23.9208 - age_output_mae: 3.5632 - gender_output_accuracy: 0.6625 - gender_output_loss: 0.6185 - loss: 24.5392 - val_age_output_loss: 424.9015 - val_age_output_mae: 18.4188 - val_gender_output_accuracy: 0.6300 - val_gender_output_loss: 0.6306 - val_loss: 423.0349
# Epoch 24/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 26.0702 - age_output_mae: 3.6722 - gender_output_accuracy: 0.6507 - gender_output_loss: 0.6205 - loss: 26.6907 - val_age_output_loss: 259.8460 - val_age_output_mae: 13.6038 - val_gender_output_accuracy: 0.6810 - val_gender_output_loss: 0.6080 - val_loss: 258.6364
# Epoch 25/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 23.5553 - age_output_mae: 3.5269 - gender_output_accuracy: 0.6592 - gender_output_loss: 0.6208 - loss: 24.1761 - val_age_output_loss: 201.8001 - val_age_output_mae: 11.9984 - val_gender_output_accuracy: 0.6340 - val_gender_output_loss: 0.6273 - val_loss: 202.5685
# Epoch 26/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 23.2469 - age_output_mae: 3.5624 - gender_output_accuracy: 0.6667 - gender_output_loss: 0.6135 - loss: 23.8605 - val_age_output_loss: 231.8173 - val_age_output_mae: 12.6092 - val_gender_output_accuracy: 0.6870 - val_gender_output_loss: 0.6140 - val_loss: 229.4512
# Epoch 27/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 20.7205 - age_output_mae: 3.3379 - gender_output_accuracy: 0.6757 - gender_output_loss: 0.6082 - loss: 21.3287 - val_age_output_loss: 399.6750 - val_age_output_mae: 17.3990 - val_gender_output_accuracy: 0.5900 - val_gender_output_loss: 0.6528 - val_loss: 395.4395
# Epoch 28/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 22.1709 - age_output_mae: 3.4263 - gender_output_accuracy: 0.6836 - gender_output_loss: 0.6077 - loss: 22.7787 - val_age_output_loss: 311.1029 - val_age_output_mae: 14.9376 - val_gender_output_accuracy: 0.6920 - val_gender_output_loss: 0.5903 - val_loss: 308.2779
# Epoch 29/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - age_output_loss: 18.7105 - age_output_mae: 3.1751 - gender_output_accuracy: 0.6824 - gender_output_loss: 0.6036 - loss: 19.3141 - val_age_output_loss: 303.9054 - val_age_output_mae: 14.7526 - val_gender_output_accuracy: 0.6620 - val_gender_output_loss: 0.6142 - val_loss: 301.5526
# Epoch 30/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 19.1745 - age_output_mae: 3.2031 - gender_output_accuracy: 0.6613 - gender_output_loss: 0.6130 - loss: 19.7875 - val_age_output_loss: 164.9351 - val_age_output_mae: 10.2022 - val_gender_output_accuracy: 0.6900 - val_gender_output_loss: 0.5960 - val_loss: 163.2137
# Epoch 31/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 17.7159 - age_output_mae: 3.1175 - gender_output_accuracy: 0.6629 - gender_output_loss: 0.6051 - loss: 18.3209 - val_age_output_loss: 110.4268 - val_age_output_mae: 8.2486 - val_gender_output_accuracy: 0.7120 - val_gender_output_loss: 0.5724 - val_loss: 109.0046
# Epoch 32/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 17.3240 - age_output_mae: 3.0137 - gender_output_accuracy: 0.6783 - gender_output_loss: 0.6000 - loss: 17.9239 - val_age_output_loss: 160.9131 - val_age_output_mae: 10.3195 - val_gender_output_accuracy: 0.7310 - val_gender_output_loss: 0.5649 - val_loss: 160.5225
# Epoch 33/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 17.0952 - age_output_mae: 3.0130 - gender_output_accuracy: 0.6758 - gender_output_loss: 0.5998 - loss: 17.6950 - val_age_output_loss: 105.5016 - val_age_output_mae: 7.9522 - val_gender_output_accuracy: 0.7440 - val_gender_output_loss: 0.5562 - val_loss: 105.0650
# Epoch 34/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 17.4632 - age_output_mae: 3.0593 - gender_output_accuracy: 0.6988 - gender_output_loss: 0.5884 - loss: 18.0516 - val_age_output_loss: 106.4379 - val_age_output_mae: 7.7957 - val_gender_output_accuracy: 0.7390 - val_gender_output_loss: 0.5506 - val_loss: 106.6172
# Epoch 35/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 16.1130 - age_output_mae: 2.9512 - gender_output_accuracy: 0.6762 - gender_output_loss: 0.5995 - loss: 16.7125 - val_age_output_loss: 100.4661 - val_age_output_mae: 7.7892 - val_gender_output_accuracy: 0.7230 - val_gender_output_loss: 0.5613 - val_loss: 100.1419
# Epoch 36/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 15.5961 - age_output_mae: 2.8951 - gender_output_accuracy: 0.6936 - gender_output_loss: 0.5868 - loss: 16.1829 - val_age_output_loss: 159.9865 - val_age_output_mae: 9.8122 - val_gender_output_accuracy: 0.7310 - val_gender_output_loss: 0.5454 - val_loss: 157.3191
# Epoch 37/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 19.8636 - age_output_mae: 3.2001 - gender_output_accuracy: 0.6970 - gender_output_loss: 0.5818 - loss: 20.4454 - val_age_output_loss: 88.9131 - val_age_output_mae: 7.3453 - val_gender_output_accuracy: 0.7380 - val_gender_output_loss: 0.5371 - val_loss: 89.2322
# Epoch 38/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - age_output_loss: 16.8427 - age_output_mae: 2.9386 - gender_output_accuracy: 0.6972 - gender_output_loss: 0.5808 - loss: 17.4235 - val_age_output_loss: 102.9106 - val_age_output_mae: 7.8308 - val_gender_output_accuracy: 0.7450 - val_gender_output_loss: 0.5366 - val_loss: 102.3364
# Epoch 39/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 15.3432 - age_output_mae: 2.8415 - gender_output_accuracy: 0.6931 - gender_output_loss: 0.5814 - loss: 15.9246 - val_age_output_loss: 73.7315 - val_age_output_mae: 6.3932 - val_gender_output_accuracy: 0.7430 - val_gender_output_loss: 0.5385 - val_loss: 73.4976
# Epoch 40/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 16.3577 - age_output_mae: 2.9070 - gender_output_accuracy: 0.7191 - gender_output_loss: 0.5673 - loss: 16.9250 - val_age_output_loss: 107.5534 - val_age_output_mae: 8.0365 - val_gender_output_accuracy: 0.7510 - val_gender_output_loss: 0.5264 - val_loss: 107.9298
# Epoch 41/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - age_output_loss: 16.3737 - age_output_mae: 2.9774 - gender_output_accuracy: 0.7047 - gender_output_loss: 0.5713 - loss: 16.9450 - val_age_output_loss: 97.2150 - val_age_output_mae: 7.7546 - val_gender_output_accuracy: 0.7500 - val_gender_output_loss: 0.5324 - val_loss: 97.4223
# Epoch 42/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - age_output_loss: 16.1050 - age_output_mae: 2.8730 - gender_output_accuracy: 0.6992 - gender_output_loss: 0.5717 - loss: 16.6767 - val_age_output_loss: 95.8278 - val_age_output_mae: 7.6118 - val_gender_output_accuracy: 0.7490 - val_gender_output_loss: 0.5237 - val_loss: 95.4926
# Epoch 43/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - age_output_loss: 15.5176 - age_output_mae: 2.8624 - gender_output_accuracy: 0.7189 - gender_output_loss: 0.5498 - loss: 16.0674 - val_age_output_loss: 75.3046 - val_age_output_mae: 6.5173 - val_gender_output_accuracy: 0.7450 - val_gender_output_loss: 0.5260 - val_loss: 75.4765
# Epoch 44/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 14.2092 - age_output_mae: 2.7586 - gender_output_accuracy: 0.7254 - gender_output_loss: 0.5556 - loss: 14.7648 - val_age_output_loss: 83.8868 - val_age_output_mae: 6.8491 - val_gender_output_accuracy: 0.7450 - val_gender_output_loss: 0.5298 - val_loss: 84.4163
# Epoch 45/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 16.7896 - age_output_mae: 2.9449 - gender_output_accuracy: 0.7213 - gender_output_loss: 0.5571 - loss: 17.3467 - val_age_output_loss: 80.5319 - val_age_output_mae: 6.5922 - val_gender_output_accuracy: 0.7610 - val_gender_output_loss: 0.5220 - val_loss: 79.8848
# Epoch 46/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 15.4854 - age_output_mae: 2.8076 - gender_output_accuracy: 0.7129 - gender_output_loss: 0.5616 - loss: 16.0469 - val_age_output_loss: 94.4686 - val_age_output_mae: 7.2047 - val_gender_output_accuracy: 0.7640 - val_gender_output_loss: 0.5176 - val_loss: 93.6471
# Epoch 47/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - age_output_loss: 12.9165 - age_output_mae: 2.5978 - gender_output_accuracy: 0.7404 - gender_output_loss: 0.5491 - loss: 13.4657 - val_age_output_loss: 80.0171 - val_age_output_mae: 6.6730 - val_gender_output_accuracy: 0.7630 - val_gender_output_loss: 0.5087 - val_loss: 80.5209
# Epoch 48/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - age_output_loss: 14.3417 - age_output_mae: 2.6922 - gender_output_accuracy: 0.7109 - gender_output_loss: 0.5521 - loss: 14.8938 - val_age_output_loss: 87.1666 - val_age_output_mae: 7.0330 - val_gender_output_accuracy: 0.7680 - val_gender_output_loss: 0.5061 - val_loss: 87.4572
# Epoch 49/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - age_output_loss: 13.6335 - age_output_mae: 2.7169 - gender_output_accuracy: 0.7292 - gender_output_loss: 0.5361 - loss: 14.1697 - val_age_output_loss: 89.3986 - val_age_output_mae: 7.1376 - val_gender_output_accuracy: 0.7550 - val_gender_output_loss: 0.5084 - val_loss: 89.4610
# Epoch 50/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 14.2269 - age_output_mae: 2.7072 - gender_output_accuracy: 0.7111 - gender_output_loss: 0.5630 - loss: 14.7900 - val_age_output_loss: 77.0409 - val_age_output_mae: 6.3834 - val_gender_output_accuracy: 0.7510 - val_gender_output_loss: 0.5244 - val_loss: 76.8404
# Epoch 51/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - age_output_loss: 13.4001 - age_output_mae: 2.6511 - gender_output_accuracy: 0.7270 - gender_output_loss: 0.5470 - loss: 13.9471 - val_age_output_loss: 80.3055 - val_age_output_mae: 6.6575 - val_gender_output_accuracy: 0.7490 - val_gender_output_loss: 0.5167 - val_loss: 80.5645
# Epoch 52/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 14.3058 - age_output_mae: 2.7601 - gender_output_accuracy: 0.7474 - gender_output_loss: 0.5209 - loss: 14.8267 - val_age_output_loss: 75.3953 - val_age_output_mae: 6.4574 - val_gender_output_accuracy: 0.7490 - val_gender_output_loss: 0.5118 - val_loss: 74.9781
# Epoch 53/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 15.2550 - age_output_mae: 2.8450 - gender_output_accuracy: 0.7355 - gender_output_loss: 0.5306 - loss: 15.7857 - val_age_output_loss: 85.0976 - val_age_output_mae: 6.9714 - val_gender_output_accuracy: 0.7540 - val_gender_output_loss: 0.5065 - val_loss: 85.1844
# Epoch 54/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 13.0672 - age_output_mae: 2.5898 - gender_output_accuracy: 0.7470 - gender_output_loss: 0.5104 - loss: 13.5776 - val_age_output_loss: 69.9508 - val_age_output_mae: 6.0116 - val_gender_output_accuracy: 0.7660 - val_gender_output_loss: 0.4911 - val_loss: 69.9379
# Epoch 55/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - age_output_loss: 15.2762 - age_output_mae: 2.8220 - gender_output_accuracy: 0.7461 - gender_output_loss: 0.5187 - loss: 15.7949 - val_age_output_loss: 74.7536 - val_age_output_mae: 6.2236 - val_gender_output_accuracy: 0.7700 - val_gender_output_loss: 0.4867 - val_loss: 74.8548
# Epoch 56/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 14.4326 - age_output_mae: 2.7127 - gender_output_accuracy: 0.7516 - gender_output_loss: 0.5036 - loss: 14.9362 - val_age_output_loss: 71.7837 - val_age_output_mae: 6.0558 - val_gender_output_accuracy: 0.7700 - val_gender_output_loss: 0.4729 - val_loss: 71.8521
# Epoch 57/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 14.4385 - age_output_mae: 2.6671 - gender_output_accuracy: 0.7465 - gender_output_loss: 0.5086 - loss: 14.9471 - val_age_output_loss: 80.5035 - val_age_output_mae: 6.5833 - val_gender_output_accuracy: 0.7740 - val_gender_output_loss: 0.4760 - val_loss: 79.5868
# Epoch 58/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 13.7036 - age_output_mae: 2.6293 - gender_output_accuracy: 0.7633 - gender_output_loss: 0.4946 - loss: 14.1983 - val_age_output_loss: 80.1957 - val_age_output_mae: 6.8040 - val_gender_output_accuracy: 0.7670 - val_gender_output_loss: 0.4670 - val_loss: 80.6041
# Epoch 59/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 13.8015 - age_output_mae: 2.6428 - gender_output_accuracy: 0.7557 - gender_output_loss: 0.5027 - loss: 14.3042 - val_age_output_loss: 90.4213 - val_age_output_mae: 7.1965 - val_gender_output_accuracy: 0.7750 - val_gender_output_loss: 0.4671 - val_loss: 89.8874
# Epoch 60/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 13.3078 - age_output_mae: 2.6221 - gender_output_accuracy: 0.7550 - gender_output_loss: 0.4939 - loss: 13.8017 - val_age_output_loss: 68.9852 - val_age_output_mae: 5.9811 - val_gender_output_accuracy: 0.7770 - val_gender_output_loss: 0.4535 - val_loss: 69.0945
# Epoch 61/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - age_output_loss: 13.9253 - age_output_mae: 2.6739 - gender_output_accuracy: 0.7523 - gender_output_loss: 0.4925 - loss: 14.4179 - val_age_output_loss: 75.5480 - val_age_output_mae: 6.4806 - val_gender_output_accuracy: 0.7760 - val_gender_output_loss: 0.4560 - val_loss: 75.5053
# Epoch 62/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - age_output_loss: 12.6805 - age_output_mae: 2.5799 - gender_output_accuracy: 0.7494 - gender_output_loss: 0.4858 - loss: 13.1663 - val_age_output_loss: 70.1075 - val_age_output_mae: 6.1028 - val_gender_output_accuracy: 0.7930 - val_gender_output_loss: 0.4450 - val_loss: 70.2212
# Epoch 63/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 13.4017 - age_output_mae: 2.6286 - gender_output_accuracy: 0.7681 - gender_output_loss: 0.4719 - loss: 13.8736 - val_age_output_loss: 73.2422 - val_age_output_mae: 6.3401 - val_gender_output_accuracy: 0.8000 - val_gender_output_loss: 0.4424 - val_loss: 73.3503
# Epoch 64/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 12.3630 - age_output_mae: 2.5057 - gender_output_accuracy: 0.7777 - gender_output_loss: 0.4652 - loss: 12.8281 - val_age_output_loss: 71.8599 - val_age_output_mae: 6.1779 - val_gender_output_accuracy: 0.7980 - val_gender_output_loss: 0.4287 - val_loss: 71.4604
# Epoch 65/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 16.1157 - age_output_mae: 2.8804 - gender_output_accuracy: 0.7889 - gender_output_loss: 0.4550 - loss: 16.5707 - val_age_output_loss: 75.5742 - val_age_output_mae: 6.3577 - val_gender_output_accuracy: 0.7860 - val_gender_output_loss: 0.4425 - val_loss: 75.7875
# Epoch 66/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - age_output_loss: 14.3718 - age_output_mae: 2.6645 - gender_output_accuracy: 0.7626 - gender_output_loss: 0.4714 - loss: 14.8432 - val_age_output_loss: 69.9964 - val_age_output_mae: 6.0625 - val_gender_output_accuracy: 0.8030 - val_gender_output_loss: 0.4215 - val_loss: 70.2016
# Epoch 67/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - age_output_loss: 12.0393 - age_output_mae: 2.5116 - gender_output_accuracy: 0.7678 - gender_output_loss: 0.4730 - loss: 12.5123 - val_age_output_loss: 77.5506 - val_age_output_mae: 6.5147 - val_gender_output_accuracy: 0.7850 - val_gender_output_loss: 0.4353 - val_loss: 77.3404
# Epoch 68/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - age_output_loss: 13.7327 - age_output_mae: 2.6275 - gender_output_accuracy: 0.7810 - gender_output_loss: 0.4549 - loss: 14.1875 - val_age_output_loss: 73.5515 - val_age_output_mae: 6.2597 - val_gender_output_accuracy: 0.8130 - val_gender_output_loss: 0.4191 - val_loss: 73.3394
# Epoch 69/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 14.0441 - age_output_mae: 2.7069 - gender_output_accuracy: 0.7913 - gender_output_loss: 0.4462 - loss: 14.4903 - val_age_output_loss: 87.0595 - val_age_output_mae: 7.0971 - val_gender_output_accuracy: 0.8090 - val_gender_output_loss: 0.4122 - val_loss: 86.6239
# Epoch 70/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - age_output_loss: 13.2228 - age_output_mae: 2.5525 - gender_output_accuracy: 0.7890 - gender_output_loss: 0.4453 - loss: 13.6681 - val_age_output_loss: 68.4422 - val_age_output_mae: 5.9691 - val_gender_output_accuracy: 0.7940 - val_gender_output_loss: 0.4191 - val_loss: 68.2223
# Epoch 71/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 9.8899 - age_output_mae: 2.2861 - gender_output_accuracy: 0.7943 - gender_output_loss: 0.4390 - loss: 10.3289 - val_age_output_loss: 68.2085 - val_age_output_mae: 5.9731 - val_gender_output_accuracy: 0.8010 - val_gender_output_loss: 0.4162 - val_loss: 67.8620
# Epoch 72/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 12.2270 - age_output_mae: 2.5215 - gender_output_accuracy: 0.8014 - gender_output_loss: 0.4300 - loss: 12.6570 - val_age_output_loss: 73.3598 - val_age_output_mae: 6.3083 - val_gender_output_accuracy: 0.8070 - val_gender_output_loss: 0.4046 - val_loss: 73.2184
# Epoch 73/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 11.1047 - age_output_mae: 2.3863 - gender_output_accuracy: 0.7933 - gender_output_loss: 0.4319 - loss: 11.5366 - val_age_output_loss: 67.3926 - val_age_output_mae: 5.8712 - val_gender_output_accuracy: 0.8020 - val_gender_output_loss: 0.3960 - val_loss: 67.5971
# Epoch 74/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 11.6825 - age_output_mae: 2.4468 - gender_output_accuracy: 0.7882 - gender_output_loss: 0.4372 - loss: 12.1197 - val_age_output_loss: 69.0650 - val_age_output_mae: 6.0104 - val_gender_output_accuracy: 0.8010 - val_gender_output_loss: 0.3960 - val_loss: 69.0344
# Epoch 75/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - age_output_loss: 11.9168 - age_output_mae: 2.4447 - gender_output_accuracy: 0.7953 - gender_output_loss: 0.4218 - loss: 12.3386 - val_age_output_loss: 67.8315 - val_age_output_mae: 5.9767 - val_gender_output_accuracy: 0.8060 - val_gender_output_loss: 0.3956 - val_loss: 67.7695
# Epoch 76/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 11.3611 - age_output_mae: 2.3744 - gender_output_accuracy: 0.7992 - gender_output_loss: 0.4276 - loss: 11.7887 - val_age_output_loss: 80.3674 - val_age_output_mae: 6.7016 - val_gender_output_accuracy: 0.8180 - val_gender_output_loss: 0.3963 - val_loss: 80.1373
# Epoch 77/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 10.4561 - age_output_mae: 2.3072 - gender_output_accuracy: 0.8049 - gender_output_loss: 0.4056 - loss: 10.8616 - val_age_output_loss: 74.3915 - val_age_output_mae: 6.4211 - val_gender_output_accuracy: 0.8020 - val_gender_output_loss: 0.3940 - val_loss: 74.3610
# Epoch 78/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 11.1526 - age_output_mae: 2.4257 - gender_output_accuracy: 0.7967 - gender_output_loss: 0.4172 - loss: 11.5697 - val_age_output_loss: 69.6732 - val_age_output_mae: 6.1018 - val_gender_output_accuracy: 0.8020 - val_gender_output_loss: 0.3989 - val_loss: 69.7696
# Epoch 79/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 12.1462 - age_output_mae: 2.4717 - gender_output_accuracy: 0.8033 - gender_output_loss: 0.4068 - loss: 12.5531 - val_age_output_loss: 67.4227 - val_age_output_mae: 5.8494 - val_gender_output_accuracy: 0.7940 - val_gender_output_loss: 0.3960 - val_loss: 67.5495
# Epoch 80/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - age_output_loss: 9.8805 - age_output_mae: 2.2787 - gender_output_accuracy: 0.8012 - gender_output_loss: 0.4134 - loss: 10.2939 - val_age_output_loss: 65.6809 - val_age_output_mae: 5.8459 - val_gender_output_accuracy: 0.8170 - val_gender_output_loss: 0.3839 - val_loss: 65.9245
# Epoch 81/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 11.1820 - age_output_mae: 2.3705 - gender_output_accuracy: 0.8025 - gender_output_loss: 0.4172 - loss: 11.5992 - val_age_output_loss: 67.6894 - val_age_output_mae: 5.9039 - val_gender_output_accuracy: 0.8200 - val_gender_output_loss: 0.3753 - val_loss: 67.6800
# Epoch 82/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 12.2020 - age_output_mae: 2.4961 - gender_output_accuracy: 0.8133 - gender_output_loss: 0.4123 - loss: 12.6143 - val_age_output_loss: 67.4908 - val_age_output_mae: 5.9568 - val_gender_output_accuracy: 0.8090 - val_gender_output_loss: 0.3748 - val_loss: 67.5896
# Epoch 83/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - age_output_loss: 12.4410 - age_output_mae: 2.4985 - gender_output_accuracy: 0.8172 - gender_output_loss: 0.4024 - loss: 12.8435 - val_age_output_loss: 70.8162 - val_age_output_mae: 6.2739 - val_gender_output_accuracy: 0.8120 - val_gender_output_loss: 0.3742 - val_loss: 71.1392
# Epoch 84/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - age_output_loss: 10.1163 - age_output_mae: 2.3049 - gender_output_accuracy: 0.8167 - gender_output_loss: 0.4030 - loss: 10.5193 - val_age_output_loss: 69.0919 - val_age_output_mae: 5.9404 - val_gender_output_accuracy: 0.8200 - val_gender_output_loss: 0.3720 - val_loss: 69.5820
# Epoch 85/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 12.3000 - age_output_mae: 2.5170 - gender_output_accuracy: 0.8088 - gender_output_loss: 0.4056 - loss: 12.7056 - val_age_output_loss: 66.3557 - val_age_output_mae: 5.8513 - val_gender_output_accuracy: 0.8200 - val_gender_output_loss: 0.3645 - val_loss: 66.6221
# Epoch 86/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 10.4652 - age_output_mae: 2.3107 - gender_output_accuracy: 0.8154 - gender_output_loss: 0.3816 - loss: 10.8468 - val_age_output_loss: 70.9079 - val_age_output_mae: 6.2761 - val_gender_output_accuracy: 0.8220 - val_gender_output_loss: 0.3656 - val_loss: 71.2134
# Epoch 87/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 12.0005 - age_output_mae: 2.4697 - gender_output_accuracy: 0.8183 - gender_output_loss: 0.3880 - loss: 12.3884 - val_age_output_loss: 67.5300 - val_age_output_mae: 5.8307 - val_gender_output_accuracy: 0.8210 - val_gender_output_loss: 0.3637 - val_loss: 67.5871
# Epoch 88/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 11.5333 - age_output_mae: 2.4072 - gender_output_accuracy: 0.8053 - gender_output_loss: 0.4035 - loss: 11.9369 - val_age_output_loss: 70.4542 - val_age_output_mae: 6.0910 - val_gender_output_accuracy: 0.8220 - val_gender_output_loss: 0.3731 - val_loss: 70.1332
# Epoch 89/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 10.5780 - age_output_mae: 2.3227 - gender_output_accuracy: 0.8139 - gender_output_loss: 0.4051 - loss: 10.9831 - val_age_output_loss: 66.8484 - val_age_output_mae: 5.8747 - val_gender_output_accuracy: 0.8290 - val_gender_output_loss: 0.3684 - val_loss: 66.7185
# Epoch 90/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - age_output_loss: 10.8068 - age_output_mae: 2.3810 - gender_output_accuracy: 0.8170 - gender_output_loss: 0.3923 - loss: 11.1992 - val_age_output_loss: 73.6302 - val_age_output_mae: 6.2899 - val_gender_output_accuracy: 0.8200 - val_gender_output_loss: 0.3715 - val_loss: 73.0368
# Epoch 91/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 11.2945 - age_output_mae: 2.4069 - gender_output_accuracy: 0.8278 - gender_output_loss: 0.3728 - loss: 11.6673 - val_age_output_loss: 69.5359 - val_age_output_mae: 5.9783 - val_gender_output_accuracy: 0.8160 - val_gender_output_loss: 0.3767 - val_loss: 69.2162
# Epoch 92/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 10.7269 - age_output_mae: 2.3340 - gender_output_accuracy: 0.8191 - gender_output_loss: 0.3895 - loss: 11.1164 - val_age_output_loss: 70.9808 - val_age_output_mae: 6.1298 - val_gender_output_accuracy: 0.8180 - val_gender_output_loss: 0.3581 - val_loss: 70.6321
# Epoch 93/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - age_output_loss: 11.6043 - age_output_mae: 2.3833 - gender_output_accuracy: 0.8176 - gender_output_loss: 0.3860 - loss: 11.9903 - val_age_output_loss: 70.4746 - val_age_output_mae: 6.0803 - val_gender_output_accuracy: 0.8260 - val_gender_output_loss: 0.3628 - val_loss: 69.8359
# Epoch 94/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - age_output_loss: 11.2741 - age_output_mae: 2.3749 - gender_output_accuracy: 0.8291 - gender_output_loss: 0.3808 - loss: 11.6549 - val_age_output_loss: 67.9835 - val_age_output_mae: 5.9149 - val_gender_output_accuracy: 0.8200 - val_gender_output_loss: 0.3723 - val_loss: 68.1187
# Epoch 95/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 10.1546 - age_output_mae: 2.2580 - gender_output_accuracy: 0.8190 - gender_output_loss: 0.3759 - loss: 10.5305 - val_age_output_loss: 70.1588 - val_age_output_mae: 5.9841 - val_gender_output_accuracy: 0.8270 - val_gender_output_loss: 0.3675 - val_loss: 70.0849

# %% [markdown]
# ## STEP4B: Draw the learning curves
# Draw four learning curve figures for model B as follows.
# 1. The loss of the gender classification over the training and validation set
# 2. The accuracy of the gender classification over the training and validation set
# 3. The loss of the age estimation over the training and validation set
# 4. The MAE of the age estimation over the training and validation set

# %%
#
# Gender Classification Training and Validation Loss

plt.figure(figsize=(10,6))
plt.plot(history.history['gender_output_loss'], label='Training Loss')
plt.plot(history.history['val_gender_output_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.title('Gender Classification Training and Validation Loss')
plt.grid(True)
plt.ylim([0,1.0])
plt.legend()
plt.show()

# Gender Classification Training and Validation Accuracy

plt.figure(figsize=(10,6))
plt.plot(history.history['gender_output_accuracy'], label='Training Accuracy')
plt.plot(history.history['val_gender_output_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.title('Gender Classification Training and Validation Accuracy')
plt.grid(True)
plt.ylim([0,1.0])
plt.legend()
plt.show()

# Age Estimation Training and Validation Loss

plt.figure(figsize=(10,6))
plt.plot(history.history['age_output_loss'], label='Training Loss')
plt.plot(history.history['val_age_output_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.title('Age Estimation Training and Validation Loss')
plt.grid(True)
plt.legend()
plt.show()

# Age Estimation Training and Validation MAE

plt.figure(figsize=(10,6))
plt.plot(history.history['age_output_mae'], label='Mean Absolute Error (MAE) of Training Set')
plt.plot(history.history['val_age_output_mae'], label='Mean Absolute Error (MAE) of Validation Set')
plt.xlabel('Epoch')
plt.title('MAE of Age Estimation for Training and Validation Sets')
plt.grid(True)
plt.legend()
plt.show()
#

# %% [markdown]
# ## STEP5: Evaluate the model on the test set
# I will load your two models for testing. The test set will not be available before your submission.
#
# The metrics for measuring the performance on the test set are:
# - age estimation: MAE (Mean Absolute Error)
# - gender classification: accuracy

# %%
#
# Don't add code in this cell when submitting this file
#
