# %% [markdown]
# <a href="https://colab.research.google.com/github/GianUOM/UniBath-Courseworks/blob/main/UnderstandingDeepLearning/age_gender_submit%20(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Age Estimation and Gender Classification
#
# In this assignment, you will train CNN models to estimate a person's age and predict their gender based on face images. Please read carefully all the instructions before you start to write your code.
#
# **Your Tasks**
#
# You are supposed to train two CNN models.
# - Model A: Train a CNN model from scratch, following a few restrictions. Save this model as `age_gender_A.keras`
# - Model B: Fine-tune a pre-trained model to perform the same task. Save this model as `age_gender_B.keras`
#
# **Dataset**
#
# Your models will be trained and validated on a folder `train_val/` containing 5,000 labeled face images (size: 128 x 128), originated from the UTKFace dataset. During the assessment phase, your code will be tested on unseen test data.
#
# **Performance Metric**
#
# The evaluation of your models on the test set will be based on the following metrics:
# - age estimation: - Mean Absolute Error (MAE)
# - gender prediction: accuracy
#
# **GPU Time Management**
#
# Please use the available GPU time wisely, as there are some limitations on free GPU usage. It is said the users can use up to 12 hours in row in Google Colab. But many people found they reached its limit far less than 12 hours. To minimize the risk of reaching the limit, consider the following suggestions:
# 1. Ensure you have a stable internet connection.
# 2. Carefully validate your hyperparameters before starting the training process.
# 3. Based on past experience, each model should be trained in less than 2 hours. If the training time is significantly longer, you may need to adjust your model architecture.

# %% [markdown]
# ## Setting Up: Mount the google drive
# Mount your google drive to the notebook. Also don't forget to **enable GPU** before your training.

# %%
#
from google.colab import drive
drive.mount('/content/drive')
#
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Visualize a few photos
# It's always beneficial to thoroughly understand your data before beginning the training process. To get a first-hand impression of the dataset, please display a minimum of 20 images from the `train_val/` folder, along with their corresponding age and gender labels. This will help you gain initial insights into the dataset.

# %%
#
import os
import random
import cv2
import matplotlib.pyplot as plt

folder_train_val = "/content/drive/MyDrive/Colab Notebooks/DeepLearningAssignment/train_val"
# folder_train_val = "/Users/gianlucaaquilina/Downloads/train_val"
all_image_files = [file for file in os.listdir(folder_train_val) if file.lower().endswith(('.jpg'))]

random.seed(42)
sample_images = random.sample(all_image_files, min(20, len(all_image_files)))

plt.figure(figsize=(15, 10))

for i, image_file in enumerate(sample_images, 1):
    img_path = os.path.join(folder_train_val, image_file)
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    labels = image_file.split('_')
    age_label = int(labels[0])
    gender_label = "Male" if labels[1] == "0" else "Female"

    plt.subplot(4, 5, i)
    plt.imshow(img)
    plt.title(f"Age: {age_label}\nGender: {gender_label}")
    plt.axis('off')

plt.tight_layout()
plt.show()
#

# %% [markdown]
# ## Step 1: Data Pre-Processing
# In this step, you will perform necessary pre-processing tasks before feeding the data into a CNN. The pre-processing includes:
#
# 1. Splitting the data into training and validation sets.
# 2. Loading image data, gender labels and age values, and rescaling pixel values (originally integers between 0 and 255) to the range [0, 1].
# 3. Data augmentation
#
# The first two pre-processing steps have already been completed for you. Your task in this step is limited to:
#
# 3. Data augmentation
#
# Please note:
#
# - Do not modify any part of the provided code except the section marked with ########.
# - Do not rescale the age values to the range [0,1], as the original values are used during the testing stage. Rescaling them would significantly impact testing performance.

# %%
import os
import random
import numpy as np
from tensorflow.keras import layers, Sequential

folder_train_val = "/content/drive/MyDrive/Colab Notebooks/DeepLearningAssignment/train_val"
# folder_train_val = "/Users/gianlucaaquilina/Downloads/train_val"
all_image_files = [file for file in os.listdir(folder_train_val) if file.lower().endswith(('.jpg'))]

# Shuffle the dataset to ensure random distribution
random.seed(0)  # Ensure reproducibility
random.shuffle(all_image_files)

# Calculate the number of images for each set
n_train_val = len(all_image_files)
train_end = int(n_train_val * 0.8)

# Split the dataset
train_image_files = all_image_files[:train_end]
val_image_files = all_image_files[train_end:]
print(f"Number of images for training: {len(train_image_files)}")
print(f"Number of images for validation: {len(val_image_files)}")

def load_imgs_lables(dataset_path,filenames):
  print('load all image data, age and gender labels...')
  images = []
  age_labels = []
  gender_labels = []
  for current_file_name in filenames:
    img = cv2.imread(os.path.join(dataset_path, current_file_name))
    img = img / 255.0  # Normalize pixel values
    labels = current_file_name.split('_')
    age_label = int(labels[0])
    gender_label = int(labels[1])
    age_labels.append(age_label)
    gender_labels.append(gender_label)
    images.append(img)

  # Convert to NumPy arrays
  images = np.array(images)
  age_labels = np.array(age_labels)
  gender_labels = np.array(gender_labels)
  return images, age_labels, gender_labels

# load data from the training set
train_images, train_age, train_gender = load_imgs_lables(folder_train_val,train_image_files)

# load data from the validation set
val_images, val_age, val_gender = load_imgs_lables(folder_train_val,val_image_files)

#
data_augmentation = Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.1),
    layers.RandomTranslation(0.1, 0.1),
    layers.RandomShear(0.1)
])
#
# Out:
# Number of images for training: 4000
# Number of images for validation: 1000
# load all image data, age and gender labels...
# load all image data, age and gender labels...

# %% [markdown]
# ## STEP2A: Build your own CNN network
# In this step, you will define your own CNN model for identifying gender and predicting age. Although there are two tasks, you only need to build one CNN model with two outputs. You may refer to online resources for solutions.
#
# Here are the key requirements and restrictions for your network:
# 1.	The input size must be 128 x 128 x 3, which means you **should not resize** the original images. This is because my test code relies on this particular input size. Any other size will cause problem in the testing stage.
# 2.  Please treat the gender classification as a binary problem, i.e., **the output layer for the gender branch has only 1 unit**, instead of 2. Although it is technically correct to treat gender classification as a multi-class problem with 2 classes, i.e., 2 units in the last layer, the test code only supports a 1-unit last-layer configuration for the gender branch.
# 3.	The size of feature maps being fed to the first fully connected layer must be less than 10 x 10, while there is no number limitation about the depth.
# 4.	Incorporate techniques to prevent overfitting as appropriate.
#
# At the end of your implementation, use `modelA.summary()` to display the model architecture and use `plot_model()` to visualize the architecture.

# %%
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf

inputs = Input(shape=(128, 128, 3))
x = data_augmentation(inputs)

x = layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
x = layers.Activation('relu')(x)
x = layers.MaxPooling2D(2, 2)(x)

x = layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
x = layers.Activation('relu')(x)
x = layers.MaxPooling2D(2, 2)(x)

x = layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
x = layers.Activation('relu')(x)
x = layers.MaxPooling2D(2, 2)(x)

x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
x = layers.Activation('relu')(x)
x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
x = layers.Activation('relu')(x)
x = layers.MaxPooling2D(2, 2)(x)

x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
x = layers.Activation('relu')(x)
x = layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(x)
x = layers.Activation('relu')(x)


age_x = layers.Flatten()(x)
age_x = layers.Dense(4608)(age_x)
age_x = layers.Activation("relu")(age_x)
age_x = layers.Dense(1024, kernel_initializer='he_uniform')(age_x)
age_x = layers.Activation("relu")(age_x)
age_x = layers.Dense(1, kernel_initializer='he_uniform')(age_x)
age_layer = layers.Activation("linear", name="age_output")(age_x)

gender_x = layers.Flatten()(x)
gender_x = layers.Dense(128, kernel_initializer='he_uniform')(gender_x)
gender_x = layers.Activation("relu")(gender_x)
gender_x = layers.BatchNormalization()(gender_x)
gender_x = layers.Dropout(0.5)(gender_x)
gender_x = layers.Dense(1, kernel_initializer='glorot_uniform')(gender_x)
gender_layer = layers.Activation("sigmoid", name="gender_output")(gender_x)

modelA = Model(inputs=inputs, outputs=[gender_layer, age_layer])

#

modelA.summary()
from tensorflow.keras.utils import plot_model
plot_model(modelA, show_shapes=True,dpi=100)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, 128, 128,  │          0 │ input_layer[0][0] │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │      1,792 │ sequential[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 128, 128,  │          0 │ conv2d[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ activation[0][0]  │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 64, 64,    │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 64, 64,    │          0 │ conv2d_1[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 32, 32,    │          0 │ conv2d_2[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ activation_2[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 16, 16,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 16, 16,    │          0 │ conv2d_3[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 16, 16,    │  2,359,808 │ activation_3[0][… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 16, 16,    │          0 │ conv2d_4[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 512) │          0 │ activation_4[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 8, 8, 512) │  2,359,808 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 8, 8, 512) │          0 │ conv2d_5[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 8, 8, 512) │  2,359,808 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 8, 8, 512) │          0 │ conv2d_6[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 32768)     │          0 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 32768)     │          0 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │  4,194,432 │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 4608)      │ 150,999,5… │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 128)       │          0 │ dense_3[0][0]     │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 4608)      │          0 │ dense[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128)       │        512 │ activation_9[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1024)      │  4,719,616 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 1024)      │          0 │ dense_1[0][0]     │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 1)         │        129 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │      1,025 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gender_output       │ (None, 1)         │          0 │ dense_4[0][0]     │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_output          │ (None, 1)         │          0 │ dense_2[0][0]     │
# │ (Activation)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 168,545,666 (642.95 MB)
#  Trainable params: 168,545,410 (642.95 MB)
#  Non-trainable params: 256 (1.00 KB)

# %% [markdown]
# ## STEP3A: Compile and train your model
# Compile and train your model here.
# Save your model by `modelA.save(your_model_folder+"age_gender_A.keras")` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Save the model with `save()`** to save the entire model (including a model's architecture, weights, and training configuration) as a `.keras` zip archive. Don't save it with `save_weights()`.

# %%
from tensorflow.keras.optimizers import Adam

modelA.compile(
    loss={'gender_output': 'binary_crossentropy', 'age_output': 'mse'},
    optimizer=Adam(learning_rate=0.0001),
    metrics={'gender_output': 'accuracy', 'age_output': 'mae'}
)

from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    min_delta=0.001,
    restore_best_weights=True,
)

epochs = 100
history = modelA.fit(
    train_images,
    {'gender_output': train_gender, 'age_output': train_age},
    validation_data=(val_images, {'gender_output': val_gender, 'age_output': val_age}),
    batch_size=32,
    callbacks=[early_stopping],
    epochs=epochs
)

folder_models = '/content/drive/MyDrive/Colab Notebooks/DeepLearningAssignment/models/'
# folder_models = '/Users/gianlucaaquilina/Documents/DeepLearning/models/'
import os
if not os.path.exists(folder_models):
  os.mkdir(folder_models)

#
modelA.save(folder_models+'age_gender_A.keras')
# Out:
# Epoch 1/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 35s 186ms/step - age_output_loss: 585.1376 - age_output_mae: 18.6565 - gender_output_accuracy: 0.5801 - gender_output_loss: 0.7581 - loss: 585.8956 - val_age_output_loss: 403.1219 - val_age_output_mae: 15.6091 - val_gender_output_accuracy: 0.5130 - val_gender_output_loss: 1.0646 - val_loss: 403.2057
# Epoch 2/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 172ms/step - age_output_loss: 473.5919 - age_output_mae: 16.9189 - gender_output_accuracy: 0.6404 - gender_output_loss: 0.6768 - loss: 474.2686 - val_age_output_loss: 365.9216 - val_age_output_mae: 14.8123 - val_gender_output_accuracy: 0.6100 - val_gender_output_loss: 0.7257 - val_loss: 364.0385
# Epoch 3/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - age_output_loss: 383.0206 - age_output_mae: 15.0673 - gender_output_accuracy: 0.6576 - gender_output_loss: 0.6714 - loss: 383.6921 - val_age_output_loss: 315.1052 - val_age_output_mae: 13.5823 - val_gender_output_accuracy: 0.5530 - val_gender_output_loss: 1.1544 - val_loss: 313.4827
# Epoch 4/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 171ms/step - age_output_loss: 350.7040 - age_output_mae: 14.3536 - gender_output_accuracy: 0.6497 - gender_output_loss: 0.6686 - loss: 351.3726 - val_age_output_loss: 287.5318 - val_age_output_mae: 12.7149 - val_gender_output_accuracy: 0.7200 - val_gender_output_loss: 0.5361 - val_loss: 284.2102
# Epoch 5/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - age_output_loss: 321.8959 - age_output_mae: 13.7698 - gender_output_accuracy: 0.6685 - gender_output_loss: 0.6440 - loss: 322.5399 - val_age_output_loss: 276.8490 - val_age_output_mae: 12.4763 - val_gender_output_accuracy: 0.5940 - val_gender_output_loss: 0.7494 - val_loss: 274.7170
# Epoch 6/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 172ms/step - age_output_loss: 340.6526 - age_output_mae: 14.2779 - gender_output_accuracy: 0.6574 - gender_output_loss: 0.6442 - loss: 341.2969 - val_age_output_loss: 268.9685 - val_age_output_mae: 12.3976 - val_gender_output_accuracy: 0.7310 - val_gender_output_loss: 0.5743 - val_loss: 267.5069
# Epoch 7/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 165ms/step - age_output_loss: 316.8018 - age_output_mae: 13.8233 - gender_output_accuracy: 0.6825 - gender_output_loss: 0.6264 - loss: 317.4283 - val_age_output_loss: 275.3079 - val_age_output_mae: 13.0065 - val_gender_output_accuracy: 0.7640 - val_gender_output_loss: 0.4952 - val_loss: 274.1750
# Epoch 8/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 171ms/step - age_output_loss: 274.0502 - age_output_mae: 12.7546 - gender_output_accuracy: 0.6728 - gender_output_loss: 0.6274 - loss: 274.6775 - val_age_output_loss: 252.6930 - val_age_output_mae: 11.4312 - val_gender_output_accuracy: 0.7200 - val_gender_output_loss: 0.5756 - val_loss: 251.0190
# Epoch 9/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - age_output_loss: 290.1391 - age_output_mae: 12.9688 - gender_output_accuracy: 0.6807 - gender_output_loss: 0.6133 - loss: 290.7523 - val_age_output_loss: 225.2635 - val_age_output_mae: 11.2175 - val_gender_output_accuracy: 0.7500 - val_gender_output_loss: 0.5228 - val_loss: 225.5769
# Epoch 10/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 270.4717 - age_output_mae: 12.4238 - gender_output_accuracy: 0.6867 - gender_output_loss: 0.6105 - loss: 271.0823 - val_age_output_loss: 230.4873 - val_age_output_mae: 11.0177 - val_gender_output_accuracy: 0.7580 - val_gender_output_loss: 0.5031 - val_loss: 231.0433
# Epoch 11/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 261.2411 - age_output_mae: 12.0577 - gender_output_accuracy: 0.6976 - gender_output_loss: 0.5760 - loss: 261.8172 - val_age_output_loss: 271.2100 - val_age_output_mae: 11.4835 - val_gender_output_accuracy: 0.7340 - val_gender_output_loss: 0.5466 - val_loss: 270.6064
# Epoch 12/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 171ms/step - age_output_loss: 249.0920 - age_output_mae: 11.7586 - gender_output_accuracy: 0.6937 - gender_output_loss: 0.5847 - loss: 249.6767 - val_age_output_loss: 214.4697 - val_age_output_mae: 10.2962 - val_gender_output_accuracy: 0.5110 - val_gender_output_loss: 1.1860 - val_loss: 215.1328
# Epoch 13/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 171ms/step - age_output_loss: 237.9889 - age_output_mae: 11.5748 - gender_output_accuracy: 0.6902 - gender_output_loss: 0.6034 - loss: 238.5923 - val_age_output_loss: 205.5233 - val_age_output_mae: 10.1710 - val_gender_output_accuracy: 0.7490 - val_gender_output_loss: 0.5659 - val_loss: 204.8045
# Epoch 14/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 165ms/step - age_output_loss: 200.6236 - age_output_mae: 10.4841 - gender_output_accuracy: 0.6998 - gender_output_loss: 0.5881 - loss: 201.2117 - val_age_output_loss: 215.3671 - val_age_output_mae: 10.8956 - val_gender_output_accuracy: 0.7490 - val_gender_output_loss: 0.5473 - val_loss: 215.8885
# Epoch 15/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - age_output_loss: 202.0155 - age_output_mae: 10.4305 - gender_output_accuracy: 0.7118 - gender_output_loss: 0.5719 - loss: 202.5874 - val_age_output_loss: 213.5802 - val_age_output_mae: 10.5260 - val_gender_output_accuracy: 0.7610 - val_gender_output_loss: 0.5012 - val_loss: 212.7775
# Epoch 16/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 165ms/step - age_output_loss: 195.2585 - age_output_mae: 10.4332 - gender_output_accuracy: 0.7198 - gender_output_loss: 0.5696 - loss: 195.8280 - val_age_output_loss: 233.1805 - val_age_output_mae: 10.6748 - val_gender_output_accuracy: 0.6890 - val_gender_output_loss: 0.7473 - val_loss: 231.4241
# Epoch 17/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - age_output_loss: 196.3528 - age_output_mae: 10.3375 - gender_output_accuracy: 0.7204 - gender_output_loss: 0.5758 - loss: 196.9286 - val_age_output_loss: 214.5806 - val_age_output_mae: 11.3974 - val_gender_output_accuracy: 0.7470 - val_gender_output_loss: 0.5701 - val_loss: 214.0737
# Epoch 18/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 22s 173ms/step - age_output_loss: 191.4056 - age_output_mae: 10.1092 - gender_output_accuracy: 0.7251 - gender_output_loss: 0.5676 - loss: 191.9732 - val_age_output_loss: 194.5318 - val_age_output_mae: 10.4932 - val_gender_output_accuracy: 0.7620 - val_gender_output_loss: 0.5685 - val_loss: 194.3872
# Epoch 19/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 171ms/step - age_output_loss: 185.5880 - age_output_mae: 10.0442 - gender_output_accuracy: 0.7004 - gender_output_loss: 0.5812 - loss: 186.1692 - val_age_output_loss: 186.5112 - val_age_output_mae: 9.5899 - val_gender_output_accuracy: 0.7610 - val_gender_output_loss: 0.5364 - val_loss: 184.6562
# Epoch 20/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 191.6248 - age_output_mae: 10.1567 - gender_output_accuracy: 0.7276 - gender_output_loss: 0.5554 - loss: 192.1802 - val_age_output_loss: 204.2706 - val_age_output_mae: 10.5622 - val_gender_output_accuracy: 0.7900 - val_gender_output_loss: 0.4735 - val_loss: 201.8339
# Epoch 21/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 171.9318 - age_output_mae: 9.5686 - gender_output_accuracy: 0.7438 - gender_output_loss: 0.5390 - loss: 172.4707 - val_age_output_loss: 189.1130 - val_age_output_mae: 9.6850 - val_gender_output_accuracy: 0.7710 - val_gender_output_loss: 0.5036 - val_loss: 185.5367
# Epoch 22/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - age_output_loss: 177.1722 - age_output_mae: 9.5590 - gender_output_accuracy: 0.7170 - gender_output_loss: 0.5723 - loss: 177.7444 - val_age_output_loss: 227.5600 - val_age_output_mae: 11.2515 - val_gender_output_accuracy: 0.7780 - val_gender_output_loss: 0.5008 - val_loss: 225.0428
# Epoch 23/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 22s 173ms/step - age_output_loss: 165.4530 - age_output_mae: 9.3534 - gender_output_accuracy: 0.7323 - gender_output_loss: 0.5508 - loss: 166.0038 - val_age_output_loss: 155.0536 - val_age_output_mae: 8.7352 - val_gender_output_accuracy: 0.7740 - val_gender_output_loss: 0.4833 - val_loss: 153.5776
# Epoch 24/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 164.3828 - age_output_mae: 9.4154 - gender_output_accuracy: 0.7120 - gender_output_loss: 0.5626 - loss: 164.9454 - val_age_output_loss: 163.1301 - val_age_output_mae: 9.0380 - val_gender_output_accuracy: 0.7890 - val_gender_output_loss: 0.4961 - val_loss: 162.3756
# Epoch 25/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 171ms/step - age_output_loss: 155.1822 - age_output_mae: 9.0692 - gender_output_accuracy: 0.7138 - gender_output_loss: 0.5625 - loss: 155.7447 - val_age_output_loss: 177.2781 - val_age_output_mae: 9.5539 - val_gender_output_accuracy: 0.7930 - val_gender_output_loss: 0.4599 - val_loss: 175.2490
# Epoch 26/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - age_output_loss: 175.1262 - age_output_mae: 9.5647 - gender_output_accuracy: 0.7358 - gender_output_loss: 0.5501 - loss: 175.6763 - val_age_output_loss: 164.6506 - val_age_output_mae: 8.8352 - val_gender_output_accuracy: 0.7700 - val_gender_output_loss: 0.4834 - val_loss: 164.6995
# Epoch 27/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 172ms/step - age_output_loss: 157.3321 - age_output_mae: 9.1732 - gender_output_accuracy: 0.7457 - gender_output_loss: 0.5229 - loss: 157.8550 - val_age_output_loss: 152.0272 - val_age_output_mae: 8.7068 - val_gender_output_accuracy: 0.8000 - val_gender_output_loss: 0.4602 - val_loss: 150.2037
# Epoch 28/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - age_output_loss: 144.7173 - age_output_mae: 8.9121 - gender_output_accuracy: 0.7272 - gender_output_loss: 0.5414 - loss: 145.2586 - val_age_output_loss: 173.4055 - val_age_output_mae: 9.8840 - val_gender_output_accuracy: 0.7980 - val_gender_output_loss: 0.4652 - val_loss: 171.8992
# Epoch 29/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - age_output_loss: 140.5670 - age_output_mae: 8.7027 - gender_output_accuracy: 0.7480 - gender_output_loss: 0.5330 - loss: 141.1000 - val_age_output_loss: 153.6257 - val_age_output_mae: 8.5971 - val_gender_output_accuracy: 0.7950 - val_gender_output_loss: 0.4625 - val_loss: 153.5013
# Epoch 30/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - age_output_loss: 143.8378 - age_output_mae: 8.7581 - gender_output_accuracy: 0.7444 - gender_output_loss: 0.5391 - loss: 144.3769 - val_age_output_loss: 172.7686 - val_age_output_mae: 9.4702 - val_gender_output_accuracy: 0.6960 - val_gender_output_loss: 0.6607 - val_loss: 168.2940
# Epoch 31/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 165ms/step - age_output_loss: 142.4426 - age_output_mae: 8.6344 - gender_output_accuracy: 0.7475 - gender_output_loss: 0.5296 - loss: 142.9722 - val_age_output_loss: 163.2043 - val_age_output_mae: 8.8990 - val_gender_output_accuracy: 0.7930 - val_gender_output_loss: 0.4470 - val_loss: 158.1791
# Epoch 32/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 136.3053 - age_output_mae: 8.4566 - gender_output_accuracy: 0.7535 - gender_output_loss: 0.5159 - loss: 136.8212 - val_age_output_loss: 158.8349 - val_age_output_mae: 8.6335 - val_gender_output_accuracy: 0.8050 - val_gender_output_loss: 0.4454 - val_loss: 157.0238
# Epoch 33/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 22s 178ms/step - age_output_loss: 131.5750 - age_output_mae: 8.3333 - gender_output_accuracy: 0.7378 - gender_output_loss: 0.5316 - loss: 132.1066 - val_age_output_loss: 141.7300 - val_age_output_mae: 8.3942 - val_gender_output_accuracy: 0.7910 - val_gender_output_loss: 0.4510 - val_loss: 138.4489
# Epoch 34/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 165ms/step - age_output_loss: 128.0973 - age_output_mae: 8.1984 - gender_output_accuracy: 0.7455 - gender_output_loss: 0.5192 - loss: 128.6164 - val_age_output_loss: 145.2982 - val_age_output_mae: 8.7402 - val_gender_output_accuracy: 0.7950 - val_gender_output_loss: 0.4444 - val_loss: 142.9767
# Epoch 35/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 132.1411 - age_output_mae: 8.3228 - gender_output_accuracy: 0.7499 - gender_output_loss: 0.5302 - loss: 132.6712 - val_age_output_loss: 176.7237 - val_age_output_mae: 9.8222 - val_gender_output_accuracy: 0.8040 - val_gender_output_loss: 0.4425 - val_loss: 173.3193
# Epoch 36/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 171ms/step - age_output_loss: 137.1470 - age_output_mae: 8.3832 - gender_output_accuracy: 0.7442 - gender_output_loss: 0.5203 - loss: 137.6673 - val_age_output_loss: 129.9596 - val_age_output_mae: 8.3036 - val_gender_output_accuracy: 0.7630 - val_gender_output_loss: 0.4714 - val_loss: 128.7345
# Epoch 37/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 172ms/step - age_output_loss: 125.2497 - age_output_mae: 8.0932 - gender_output_accuracy: 0.7526 - gender_output_loss: 0.5107 - loss: 125.7604 - val_age_output_loss: 121.7826 - val_age_output_mae: 7.8170 - val_gender_output_accuracy: 0.8040 - val_gender_output_loss: 0.4334 - val_loss: 120.3165
# Epoch 38/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 129.4555 - age_output_mae: 8.2723 - gender_output_accuracy: 0.7582 - gender_output_loss: 0.4929 - loss: 129.9483 - val_age_output_loss: 132.3860 - val_age_output_mae: 8.3528 - val_gender_output_accuracy: 0.8080 - val_gender_output_loss: 0.4351 - val_loss: 129.7328
# Epoch 39/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 117.1203 - age_output_mae: 7.7620 - gender_output_accuracy: 0.7698 - gender_output_loss: 0.4721 - loss: 117.5925 - val_age_output_loss: 140.9767 - val_age_output_mae: 8.3775 - val_gender_output_accuracy: 0.7990 - val_gender_output_loss: 0.4219 - val_loss: 138.0357
# Epoch 40/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - age_output_loss: 118.8017 - age_output_mae: 7.9536 - gender_output_accuracy: 0.7734 - gender_output_loss: 0.4966 - loss: 119.2982 - val_age_output_loss: 149.6070 - val_age_output_mae: 8.9010 - val_gender_output_accuracy: 0.7580 - val_gender_output_loss: 0.4638 - val_loss: 146.9228
# Epoch 41/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 165ms/step - age_output_loss: 129.4117 - age_output_mae: 8.2044 - gender_output_accuracy: 0.7655 - gender_output_loss: 0.4924 - loss: 129.9041 - val_age_output_loss: 143.2878 - val_age_output_mae: 8.4668 - val_gender_output_accuracy: 0.8040 - val_gender_output_loss: 0.4228 - val_loss: 139.9816
# Epoch 42/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 171ms/step - age_output_loss: 112.2678 - age_output_mae: 7.6199 - gender_output_accuracy: 0.7603 - gender_output_loss: 0.4829 - loss: 112.7507 - val_age_output_loss: 121.6919 - val_age_output_mae: 7.7989 - val_gender_output_accuracy: 0.7940 - val_gender_output_loss: 0.4734 - val_loss: 117.8357
# Epoch 43/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 105.7128 - age_output_mae: 7.3839 - gender_output_accuracy: 0.7551 - gender_output_loss: 0.4929 - loss: 106.2056 - val_age_output_loss: 123.4875 - val_age_output_mae: 8.0850 - val_gender_output_accuracy: 0.8200 - val_gender_output_loss: 0.4256 - val_loss: 121.7962
# Epoch 44/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 171ms/step - age_output_loss: 110.5753 - age_output_mae: 7.6782 - gender_output_accuracy: 0.7578 - gender_output_loss: 0.5040 - loss: 111.0793 - val_age_output_loss: 114.3607 - val_age_output_mae: 7.4777 - val_gender_output_accuracy: 0.7940 - val_gender_output_loss: 0.4485 - val_loss: 114.0400
# Epoch 45/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - age_output_loss: 106.8806 - age_output_mae: 7.4807 - gender_output_accuracy: 0.7534 - gender_output_loss: 0.5066 - loss: 107.3872 - val_age_output_loss: 145.1950 - val_age_output_mae: 8.7742 - val_gender_output_accuracy: 0.7570 - val_gender_output_loss: 0.4840 - val_loss: 142.9729
# Epoch 46/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 109.3948 - age_output_mae: 7.5199 - gender_output_accuracy: 0.7711 - gender_output_loss: 0.4790 - loss: 109.8738 - val_age_output_loss: 136.3790 - val_age_output_mae: 8.1303 - val_gender_output_accuracy: 0.8000 - val_gender_output_loss: 0.4448 - val_loss: 132.7029
# Epoch 47/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - age_output_loss: 98.3850 - age_output_mae: 7.3080 - gender_output_accuracy: 0.7601 - gender_output_loss: 0.4802 - loss: 98.8652 - val_age_output_loss: 148.2225 - val_age_output_mae: 8.4611 - val_gender_output_accuracy: 0.8090 - val_gender_output_loss: 0.4237 - val_loss: 145.0013
# Epoch 48/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - age_output_loss: 102.0199 - age_output_mae: 7.3518 - gender_output_accuracy: 0.7756 - gender_output_loss: 0.4687 - loss: 102.4886 - val_age_output_loss: 176.1279 - val_age_output_mae: 9.7566 - val_gender_output_accuracy: 0.8080 - val_gender_output_loss: 0.4114 - val_loss: 176.0823
# Epoch 49/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 95.3064 - age_output_mae: 7.1080 - gender_output_accuracy: 0.7726 - gender_output_loss: 0.4634 - loss: 95.7699 - val_age_output_loss: 125.4913 - val_age_output_mae: 8.1688 - val_gender_output_accuracy: 0.8180 - val_gender_output_loss: 0.3984 - val_loss: 123.0246
# Epoch 50/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 172ms/step - age_output_loss: 100.6672 - age_output_mae: 7.2617 - gender_output_accuracy: 0.7681 - gender_output_loss: 0.4749 - loss: 101.1421 - val_age_output_loss: 108.9051 - val_age_output_mae: 7.2860 - val_gender_output_accuracy: 0.7210 - val_gender_output_loss: 0.5264 - val_loss: 107.7759
# Epoch 51/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - age_output_loss: 88.1064 - age_output_mae: 6.8986 - gender_output_accuracy: 0.7826 - gender_output_loss: 0.4505 - loss: 88.5569 - val_age_output_loss: 119.9370 - val_age_output_mae: 7.9913 - val_gender_output_accuracy: 0.8060 - val_gender_output_loss: 0.4209 - val_loss: 119.3856
# Epoch 52/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - age_output_loss: 103.1434 - age_output_mae: 7.4401 - gender_output_accuracy: 0.7614 - gender_output_loss: 0.4792 - loss: 103.6226 - val_age_output_loss: 113.4467 - val_age_output_mae: 7.6897 - val_gender_output_accuracy: 0.7990 - val_gender_output_loss: 0.4174 - val_loss: 112.4658
# Epoch 53/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - age_output_loss: 99.7310 - age_output_mae: 7.1402 - gender_output_accuracy: 0.7724 - gender_output_loss: 0.4860 - loss: 100.2170 - val_age_output_loss: 122.7710 - val_age_output_mae: 7.9461 - val_gender_output_accuracy: 0.8070 - val_gender_output_loss: 0.4094 - val_loss: 120.5655
# Epoch 54/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 97.0163 - age_output_mae: 7.0505 - gender_output_accuracy: 0.7562 - gender_output_loss: 0.4854 - loss: 97.5017 - val_age_output_loss: 114.2612 - val_age_output_mae: 7.6395 - val_gender_output_accuracy: 0.8110 - val_gender_output_loss: 0.3915 - val_loss: 112.1022
# Epoch 55/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - age_output_loss: 93.5869 - age_output_mae: 7.0510 - gender_output_accuracy: 0.7798 - gender_output_loss: 0.4664 - loss: 94.0533 - val_age_output_loss: 115.0483 - val_age_output_mae: 7.6667 - val_gender_output_accuracy: 0.7930 - val_gender_output_loss: 0.4407 - val_loss: 114.6726
# Epoch 56/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 171ms/step - age_output_loss: 89.9438 - age_output_mae: 6.8659 - gender_output_accuracy: 0.7758 - gender_output_loss: 0.4654 - loss: 90.4092 - val_age_output_loss: 112.9299 - val_age_output_mae: 7.5041 - val_gender_output_accuracy: 0.8110 - val_gender_output_loss: 0.4058 - val_loss: 111.2796
# Epoch 57/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 171ms/step - age_output_loss: 88.7784 - age_output_mae: 6.7595 - gender_output_accuracy: 0.7656 - gender_output_loss: 0.4854 - loss: 89.2637 - val_age_output_loss: 104.9180 - val_age_output_mae: 7.2486 - val_gender_output_accuracy: 0.8190 - val_gender_output_loss: 0.3964 - val_loss: 103.7297
# Epoch 58/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 87.0422 - age_output_mae: 6.7314 - gender_output_accuracy: 0.7726 - gender_output_loss: 0.4689 - loss: 87.5110 - val_age_output_loss: 124.6851 - val_age_output_mae: 7.8463 - val_gender_output_accuracy: 0.8270 - val_gender_output_loss: 0.4048 - val_loss: 122.2267
# Epoch 59/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 87.3947 - age_output_mae: 6.8929 - gender_output_accuracy: 0.7741 - gender_output_loss: 0.4701 - loss: 87.8648 - val_age_output_loss: 113.2690 - val_age_output_mae: 7.4411 - val_gender_output_accuracy: 0.8260 - val_gender_output_loss: 0.3976 - val_loss: 109.7696
# Epoch 60/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 94.1834 - age_output_mae: 7.0752 - gender_output_accuracy: 0.7614 - gender_output_loss: 0.4652 - loss: 94.6486 - val_age_output_loss: 115.9327 - val_age_output_mae: 7.8324 - val_gender_output_accuracy: 0.8260 - val_gender_output_loss: 0.3863 - val_loss: 114.8918
# Epoch 61/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - age_output_loss: 87.7455 - age_output_mae: 6.8993 - gender_output_accuracy: 0.7887 - gender_output_loss: 0.4580 - loss: 88.2034 - val_age_output_loss: 115.7719 - val_age_output_mae: 7.5498 - val_gender_output_accuracy: 0.8040 - val_gender_output_loss: 0.4008 - val_loss: 114.8527
# Epoch 62/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 86.2336 - age_output_mae: 6.7302 - gender_output_accuracy: 0.7737 - gender_output_loss: 0.4736 - loss: 86.7072 - val_age_output_loss: 116.5130 - val_age_output_mae: 7.8100 - val_gender_output_accuracy: 0.7750 - val_gender_output_loss: 0.4466 - val_loss: 113.6836
# Epoch 63/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - age_output_loss: 80.5776 - age_output_mae: 6.5532 - gender_output_accuracy: 0.7873 - gender_output_loss: 0.4538 - loss: 81.0314 - val_age_output_loss: 137.6446 - val_age_output_mae: 8.7420 - val_gender_output_accuracy: 0.8240 - val_gender_output_loss: 0.3812 - val_loss: 136.1725
# Epoch 64/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - age_output_loss: 85.5512 - age_output_mae: 6.8103 - gender_output_accuracy: 0.7732 - gender_output_loss: 0.4736 - loss: 86.0248 - val_age_output_loss: 113.6692 - val_age_output_mae: 7.7467 - val_gender_output_accuracy: 0.8340 - val_gender_output_loss: 0.3647 - val_loss: 111.7563
# Epoch 65/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 82.5598 - age_output_mae: 6.6154 - gender_output_accuracy: 0.7678 - gender_output_loss: 0.4770 - loss: 83.0368 - val_age_output_loss: 105.8964 - val_age_output_mae: 7.1395 - val_gender_output_accuracy: 0.8110 - val_gender_output_loss: 0.4204 - val_loss: 105.0215
# Epoch 66/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - age_output_loss: 80.3804 - age_output_mae: 6.4940 - gender_output_accuracy: 0.7854 - gender_output_loss: 0.4587 - loss: 80.8391 - val_age_output_loss: 120.6496 - val_age_output_mae: 8.0271 - val_gender_output_accuracy: 0.8180 - val_gender_output_loss: 0.4117 - val_loss: 120.1911
# Epoch 67/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 22s 173ms/step - age_output_loss: 79.1484 - age_output_mae: 6.4212 - gender_output_accuracy: 0.7805 - gender_output_loss: 0.4581 - loss: 79.6064 - val_age_output_loss: 102.3635 - val_age_output_mae: 7.2210 - val_gender_output_accuracy: 0.8300 - val_gender_output_loss: 0.3825 - val_loss: 102.2435
# Epoch 68/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 72.9127 - age_output_mae: 6.1876 - gender_output_accuracy: 0.7739 - gender_output_loss: 0.4729 - loss: 73.3855 - val_age_output_loss: 114.2553 - val_age_output_mae: 7.5803 - val_gender_output_accuracy: 0.8250 - val_gender_output_loss: 0.3754 - val_loss: 113.6291
# Epoch 69/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 172ms/step - age_output_loss: 72.3381 - age_output_mae: 6.1320 - gender_output_accuracy: 0.7825 - gender_output_loss: 0.4648 - loss: 72.8029 - val_age_output_loss: 101.4001 - val_age_output_mae: 7.1933 - val_gender_output_accuracy: 0.8110 - val_gender_output_loss: 0.3815 - val_loss: 101.7940
# Epoch 70/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 74.5349 - age_output_mae: 6.2899 - gender_output_accuracy: 0.7869 - gender_output_loss: 0.4592 - loss: 74.9941 - val_age_output_loss: 139.8300 - val_age_output_mae: 8.3808 - val_gender_output_accuracy: 0.7840 - val_gender_output_loss: 0.4291 - val_loss: 137.2693
# Epoch 71/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - age_output_loss: 75.8783 - age_output_mae: 6.3897 - gender_output_accuracy: 0.7933 - gender_output_loss: 0.4323 - loss: 76.3107 - val_age_output_loss: 106.5988 - val_age_output_mae: 7.1790 - val_gender_output_accuracy: 0.8290 - val_gender_output_loss: 0.3702 - val_loss: 105.7954
# Epoch 72/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - age_output_loss: 71.0128 - age_output_mae: 6.0927 - gender_output_accuracy: 0.7872 - gender_output_loss: 0.4514 - loss: 71.4641 - val_age_output_loss: 108.8944 - val_age_output_mae: 7.6446 - val_gender_output_accuracy: 0.8130 - val_gender_output_loss: 0.3927 - val_loss: 107.9634
# Epoch 73/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 167ms/step - age_output_loss: 71.2201 - age_output_mae: 6.1414 - gender_output_accuracy: 0.7935 - gender_output_loss: 0.4452 - loss: 71.6653 - val_age_output_loss: 150.0991 - val_age_output_mae: 8.7490 - val_gender_output_accuracy: 0.7980 - val_gender_output_loss: 0.4297 - val_loss: 145.8982
# Epoch 74/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - age_output_loss: 69.4161 - age_output_mae: 6.0958 - gender_output_accuracy: 0.7670 - gender_output_loss: 0.4585 - loss: 69.8746 - val_age_output_loss: 104.1984 - val_age_output_mae: 7.1635 - val_gender_output_accuracy: 0.8250 - val_gender_output_loss: 0.3701 - val_loss: 103.6465
# Epoch 75/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - age_output_loss: 70.9872 - age_output_mae: 6.0876 - gender_output_accuracy: 0.7975 - gender_output_loss: 0.4330 - loss: 71.4202 - val_age_output_loss: 109.9255 - val_age_output_mae: 7.4386 - val_gender_output_accuracy: 0.8000 - val_gender_output_loss: 0.4061 - val_loss: 109.6179
# Epoch 76/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - age_output_loss: 80.2849 - age_output_mae: 6.5348 - gender_output_accuracy: 0.7900 - gender_output_loss: 0.4397 - loss: 80.7246 - val_age_output_loss: 107.5355 - val_age_output_mae: 7.2322 - val_gender_output_accuracy: 0.8080 - val_gender_output_loss: 0.4004 - val_loss: 107.9947
# Epoch 77/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - age_output_loss: 74.8699 - age_output_mae: 6.2971 - gender_output_accuracy: 0.7811 - gender_output_loss: 0.4504 - loss: 75.3203 - val_age_output_loss: 105.8702 - val_age_output_mae: 7.3210 - val_gender_output_accuracy: 0.8400 - val_gender_output_loss: 0.3722 - val_loss: 106.0921
# Epoch 78/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - age_output_loss: 68.4941 - age_output_mae: 6.0104 - gender_output_accuracy: 0.7848 - gender_output_loss: 0.4398 - loss: 68.9339 - val_age_output_loss: 104.4943 - val_age_output_mae: 7.4186 - val_gender_output_accuracy: 0.8320 - val_gender_output_loss: 0.3736 - val_loss: 104.6969
# Epoch 79/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - age_output_loss: 69.4362 - age_output_mae: 6.0813 - gender_output_accuracy: 0.7871 - gender_output_loss: 0.4503 - loss: 69.8865 - val_age_output_loss: 128.1941 - val_age_output_mae: 7.9441 - val_gender_output_accuracy: 0.8190 - val_gender_output_loss: 0.3698 - val_loss: 126.3969

# %% [markdown]
# ## STEP4A: Draw the learning curves
# Draw four learning curve figures for model A as follows.
# 1.	The loss of the gender classification over the training and validation set
# 2.	The accuracy of the gender classification over the training and validation set
# 3.	The loss of the age estimation over the training and validation set
# 4.	The MAE of the age estimation over the training and validation set

# %%
#
# Gender Classification Training and Validation Loss

plt.figure(figsize=(10,6))
plt.plot(history.history['gender_output_loss'], label='Training Loss')
plt.plot(history.history['val_gender_output_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.title('Gender Classification Training and Validation Loss')
plt.grid(True)
plt.ylim([0,1.0])
plt.legend()
plt.show()

# Gender Classification Training and Validation Accuracy

plt.figure(figsize=(10,6))
plt.plot(history.history['gender_output_accuracy'], label='Training Accuracy')
plt.plot(history.history['val_gender_output_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.title('Gender Classification Training and Validation Accuracy')
plt.grid(True)
plt.ylim([0,1.0])
plt.legend()
plt.show()

# Age Estimation Training and Validation Loss

plt.figure(figsize=(10,6))
plt.plot(history.history['age_output_loss'], label='Training Loss')
plt.plot(history.history['val_age_output_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.title('Age Estimation Training and Validation Loss')
plt.grid(True)
plt.legend()
plt.show()

# Age Estimation Training and Validation MAE

plt.figure(figsize=(10,6))
plt.plot(history.history['age_output_mae'], label='Mean Absolute Error (MAE) of Training Set')
plt.plot(history.history['val_age_output_mae'], label='Mean Absolute Error (MAE) of Validation Set')
plt.xlabel('Epoch')
plt.title('MAE of Age Estimation for Training and Validation Sets')
plt.grid(True)
plt.legend()
plt.show()
#

# %% [markdown]
# ## STEP2B: Build a CNN network based on a pre-trained model
# Choose an existing CNN architecture pre-trained on ImageNet and fine-tune it on this dataset.
#
# As with Model A, **do not resize the input image size**.
# Ensure that the output layer for **the gender branch has only 1 unit**.
#
# At the end of the cell, use `modelB.summary()` to display the model architecture and use `plot_model()` to visualize the architecture.

# %%
from tensorflow.keras.applications import MobileNetV2
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(128,128,3))

for layer in base_model.layers[:60]:
    layer.trainable = False


base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "mobilenetv2_1.00_128"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 64, 64,    │        864 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 64, 64,    │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 64, 64,    │          0 │ bn_Conv1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │        288 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │        128 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 64, 64,    │        512 │ expanded_conv_de… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 64, 64,    │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 64, 64,    │      1,536 │ expanded_conv_pr… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 64, 64,    │        384 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 64, 64,    │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 65, 65,    │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 32, 32,    │        864 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 32, 32,    │        384 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 32, 32,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 32, 32,    │      2,304 │ block_1_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 32, 32,    │         96 │ block_1_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 32, 32,    │      3,456 │ block_1_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 32, 32,    │        576 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 32, 32,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 32, 32,    │      1,296 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 32, 32,    │        576 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 32, 32,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 32, 32,    │      3,456 │ block_2_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 32, 32,    │         96 │ block_2_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 32, 32,    │          0 │ block_1_project_… │
# │                     │ 24)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 32, 32,    │      3,456 │ block_2_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 32, 32,    │        576 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 32, 32,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 33, 33,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 16, 16,    │      1,296 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 16, 16,    │        576 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 16, 16,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 16, 16,    │      4,608 │ block_3_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 16, 16,    │        128 │ block_3_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 16, 16,    │      6,144 │ block_3_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 16, 16,    │        768 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 16, 16,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 16, 16,    │      1,728 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 16, 16,    │        768 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 16, 16,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 16, 16,    │      6,144 │ block_4_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 16, 16,    │        128 │ block_4_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 16, 16,    │          0 │ block_3_project_… │
# │                     │ 32)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 16, 16,    │      6,144 │ block_4_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 16, 16,    │        768 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 16, 16,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 16, 16,    │      1,728 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 16, 16,    │        768 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 16, 16,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 16, 16,    │      6,144 │ block_5_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 16, 16,    │        128 │ block_5_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 16, 16,    │          0 │ block_4_add[0][0… │
# │                     │ 32)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 16, 16,    │      6,144 │ block_5_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 16, 16,    │        768 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 16, 16,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 17, 17,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 8, 8, 192) │      1,728 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 8, 8, 192) │        768 │ block_6_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 8, 8, 192) │          0 │ block_6_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 8, 8, 64)  │     12,288 │ block_6_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 8, 8, 64)  │        256 │ block_6_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 8, 8, 384) │     24,576 │ block_6_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_7_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 8, 8, 384) │          0 │ block_7_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_7_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 8, 8, 384) │          0 │ block_7_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 8, 8, 64)  │     24,576 │ block_7_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 8, 8, 64)  │        256 │ block_7_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_6_project_… │
# │                     │                   │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 8, 8, 384) │     24,576 │ block_7_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_8_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 8, 8, 384) │          0 │ block_8_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_8_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 8, 8, 384) │          0 │ block_8_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 8, 8, 64)  │     24,576 │ block_8_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 8, 8, 64)  │        256 │ block_8_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_7_add[0][0… │
# │                     │                   │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 8, 8, 384) │     24,576 │ block_8_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_9_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 8, 8, 384) │          0 │ block_9_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_9_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 8, 8, 384) │          0 │ block_9_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 8, 8, 64)  │     24,576 │ block_9_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 8, 8, 64)  │        256 │ block_9_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_8_add[0][0… │
# │                     │                   │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 8, 8, 384) │     24,576 │ block_9_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 8, 8, 384) │      1,536 │ block_10_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 8, 8, 384) │          0 │ block_10_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 8, 8, 384) │      3,456 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 8, 8, 384) │      1,536 │ block_10_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 8, 8, 384) │          0 │ block_10_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 8, 8, 96)  │     36,864 │ block_10_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 8, 8, 96)  │        384 │ block_10_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 8, 8, 576) │     55,296 │ block_10_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_11_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 8, 8, 576) │          0 │ block_11_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 8, 8, 576) │      5,184 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 8, 8, 576) │      2,304 │ block_11_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 8, 8, 576) │          0 │ block_11_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 8, 8, 96)  │     55,296 │ block_11_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 8, 8, 96)  │        384 │ block_11_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 8, 8, 96)  │          0 │ block_10_project… │
# │                     │                   │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 8, 8, 576) │     55,296 │ block_11_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_12_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 8, 8, 576) │          0 │ block_12_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 8, 8, 576) │      5,184 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 8, 8, 576) │      2,304 │ block_12_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 8, 8, 576) │          0 │ block_12_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 8, 8, 96)  │     55,296 │ block_12_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 8, 8, 96)  │        384 │ block_12_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 8, 8, 96)  │          0 │ block_11_add[0][… │
# │                     │                   │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 8, 8, 576) │     55,296 │ block_12_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_13_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 8, 8, 576) │          0 │ block_13_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 9, 9, 576) │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 4, 4, 576) │      5,184 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 4, 4, 576) │      2,304 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 4, 4, 576) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 4, 4, 160) │     92,160 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 4, 4, 160) │        640 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 4, 4, 960) │    153,600 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 4, 4, 960) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 4, 4, 960) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 4, 4, 160) │    153,600 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 4, 4, 160) │        640 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 4, 4, 160) │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 4, 4, 960) │    153,600 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 4, 4, 960) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 4, 4, 960) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 4, 4, 160) │    153,600 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 4, 4, 160) │        640 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 4, 4, 160) │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 4, 4, 960) │    153,600 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 4, 4, 960) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 4, 4, 960) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 4, 4, 320) │    307,200 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 4, 4, 320) │      1,280 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 4, 4,      │    409,600 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 4, 4,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 4, 4,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,257,984 (8.61 MB)
#  Trainable params: 2,159,744 (8.24 MB)
#  Non-trainable params: 98,240 (383.75 KB)

# %%
inputs = Input(shape=(128, 128, 3))
x = data_augmentation(inputs)

x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)

# Gender branch
gender_x = layers.Dense(128, activation='relu')(x)
gender_x = layers.Dropout(0.3)(gender_x)
gender_output = layers.Dense(1, activation='sigmoid', name='gender_output')(gender_x)

# Age branch
age_x = layers.Dense(128, activation='relu')(x)
age_x = layers.Dropout(0.3)(age_x)
age_output = layers.Dense(1, activation='linear', name='age_output')(age_x)


modelB = Model(inputs=inputs, outputs=[gender_output, age_output])

#

modelB.summary()
from tensorflow.keras.utils import plot_model
plot_model(modelB, show_shapes=True,dpi=100)
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mobilenetv2_1.00_1… │ (None, 4, 4,      │  2,257,984 │ input_layer_3[0]… │
# │ (Functional)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ mobilenetv2_1.00… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │    163,968 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 128)       │    163,968 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128)       │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gender_output       │ (None, 1)         │        129 │ dropout_2[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_output (Dense)  │ (None, 1)         │        129 │ dropout_3[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,586,178 (9.87 MB)
#  Trainable params: 2,487,938 (9.49 MB)
#  Non-trainable params: 98,240 (383.75 KB)

# %% [markdown]
# ## STEP3B: Compile and train your model
# Compile and train your model here.
# Save your model to `age_gender_B.keras` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Also, save the model with `save()` instead of `save_weights()`.**

# %%
#
from tensorflow.keras.optimizers import SGD

modelB.compile(
    loss={'gender_output': 'binary_crossentropy', 'age_output': 'mse'},
    optimizer=SGD(learning_rate=1e-4, momentum=0.9),
    metrics={'gender_output': 'accuracy', 'age_output': 'mae'}
)

from tensorflow.keras.callbacks import EarlyStopping
es_callback = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True
)

epochs = 100
history = modelB.fit(
    train_images,
    {'gender_output': train_gender, 'age_output': train_age},
    validation_data=(val_images, {'gender_output': val_gender, 'age_output': val_age}),
    epochs=epochs,
    callbacks=[es_callback]
)

your_model_folder = '/content/drive/MyDrive/Colab Notebooks/DeepLearningAssignment/models/'
#your_model_folder = '/Users/gianlucaaquilina/Documents/DeepLearning/models/'
import os
if not os.path.exists(your_model_folder):
  os.mkdir(your_model_folder)
#

modelB.save(your_model_folder+"age_gender_B.keras")
# Out:
# Epoch 1/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 59s 149ms/step - age_output_loss: 501.2117 - age_output_mae: 16.5116 - gender_output_accuracy: 0.5001 - gender_output_loss: 0.8328 - loss: 502.0444 - val_age_output_loss: 6229.6519 - val_age_output_mae: 76.7545 - val_gender_output_accuracy: 0.4870 - val_gender_output_loss: 2.1210 - val_loss: 6243.0396
# Epoch 2/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - age_output_loss: 147.5410 - age_output_mae: 8.8892 - gender_output_accuracy: 0.6117 - gender_output_loss: 0.6869 - loss: 148.2279 - val_age_output_loss: 5454.6875 - val_age_output_mae: 71.3846 - val_gender_output_accuracy: 0.4860 - val_gender_output_loss: 1.1227 - val_loss: 5448.4082
# Epoch 3/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - age_output_loss: 109.2063 - age_output_mae: 7.8937 - gender_output_accuracy: 0.6126 - gender_output_loss: 0.6688 - loss: 109.8751 - val_age_output_loss: 1728.3932 - val_age_output_mae: 37.5546 - val_gender_output_accuracy: 0.4990 - val_gender_output_loss: 0.9815 - val_loss: 1729.3656
# Epoch 4/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - age_output_loss: 91.9951 - age_output_mae: 7.0215 - gender_output_accuracy: 0.6002 - gender_output_loss: 0.6687 - loss: 92.6637 - val_age_output_loss: 1638.3861 - val_age_output_mae: 36.4749 - val_gender_output_accuracy: 0.5430 - val_gender_output_loss: 0.7305 - val_loss: 1641.8511
# Epoch 5/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - age_output_loss: 75.6430 - age_output_mae: 6.3599 - gender_output_accuracy: 0.6179 - gender_output_loss: 0.6540 - loss: 76.2970 - val_age_output_loss: 2458.1072 - val_age_output_mae: 46.9934 - val_gender_output_accuracy: 0.5730 - val_gender_output_loss: 0.7083 - val_loss: 2459.3818
# Epoch 6/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 74.5620 - age_output_mae: 6.3930 - gender_output_accuracy: 0.6056 - gender_output_loss: 0.6634 - loss: 75.2254 - val_age_output_loss: 1904.3126 - val_age_output_mae: 40.4832 - val_gender_output_accuracy: 0.5750 - val_gender_output_loss: 0.7227 - val_loss: 1897.4180
# Epoch 7/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - age_output_loss: 57.3658 - age_output_mae: 5.6294 - gender_output_accuracy: 0.6232 - gender_output_loss: 0.6529 - loss: 58.0188 - val_age_output_loss: 945.0463 - val_age_output_mae: 26.6928 - val_gender_output_accuracy: 0.5420 - val_gender_output_loss: 0.7712 - val_loss: 938.5126
# Epoch 8/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - age_output_loss: 58.1666 - age_output_mae: 5.6428 - gender_output_accuracy: 0.6324 - gender_output_loss: 0.6510 - loss: 58.8176 - val_age_output_loss: 1191.0729 - val_age_output_mae: 31.2514 - val_gender_output_accuracy: 0.6060 - val_gender_output_loss: 0.6896 - val_loss: 1180.2898
# Epoch 9/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - age_output_loss: 56.8320 - age_output_mae: 5.6732 - gender_output_accuracy: 0.6353 - gender_output_loss: 0.6406 - loss: 57.4726 - val_age_output_loss: 920.4766 - val_age_output_mae: 27.3664 - val_gender_output_accuracy: 0.5890 - val_gender_output_loss: 0.6806 - val_loss: 914.6187
# Epoch 10/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 48.5455 - age_output_mae: 5.1643 - gender_output_accuracy: 0.6373 - gender_output_loss: 0.6352 - loss: 49.1807 - val_age_output_loss: 795.4651 - val_age_output_mae: 25.7317 - val_gender_output_accuracy: 0.6450 - val_gender_output_loss: 0.6346 - val_loss: 791.2606
# Epoch 11/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - age_output_loss: 42.4946 - age_output_mae: 4.8349 - gender_output_accuracy: 0.6514 - gender_output_loss: 0.6242 - loss: 43.1187 - val_age_output_loss: 649.5057 - val_age_output_mae: 22.9590 - val_gender_output_accuracy: 0.6130 - val_gender_output_loss: 0.6822 - val_loss: 647.5507
# Epoch 12/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - age_output_loss: 38.7806 - age_output_mae: 4.6480 - gender_output_accuracy: 0.6252 - gender_output_loss: 0.6427 - loss: 39.4234 - val_age_output_loss: 635.9950 - val_age_output_mae: 22.4513 - val_gender_output_accuracy: 0.6350 - val_gender_output_loss: 0.6366 - val_loss: 631.3749
# Epoch 13/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 34.2427 - age_output_mae: 4.3774 - gender_output_accuracy: 0.6408 - gender_output_loss: 0.6339 - loss: 34.8766 - val_age_output_loss: 242.5392 - val_age_output_mae: 12.6918 - val_gender_output_accuracy: 0.6400 - val_gender_output_loss: 0.6260 - val_loss: 242.5733
# Epoch 14/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - age_output_loss: 33.1318 - age_output_mae: 4.3084 - gender_output_accuracy: 0.6473 - gender_output_loss: 0.6317 - loss: 33.7635 - val_age_output_loss: 527.9063 - val_age_output_mae: 20.4363 - val_gender_output_accuracy: 0.6410 - val_gender_output_loss: 0.6274 - val_loss: 524.4217
# Epoch 15/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - age_output_loss: 31.9205 - age_output_mae: 4.1815 - gender_output_accuracy: 0.6269 - gender_output_loss: 0.6328 - loss: 32.5533 - val_age_output_loss: 397.3991 - val_age_output_mae: 17.3005 - val_gender_output_accuracy: 0.6310 - val_gender_output_loss: 0.6501 - val_loss: 392.6917
# Epoch 16/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - age_output_loss: 25.6545 - age_output_mae: 3.7822 - gender_output_accuracy: 0.6559 - gender_output_loss: 0.6153 - loss: 26.2699 - val_age_output_loss: 291.3805 - val_age_output_mae: 14.6189 - val_gender_output_accuracy: 0.6150 - val_gender_output_loss: 0.6590 - val_loss: 288.4204
# Epoch 17/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 27.6758 - age_output_mae: 3.8545 - gender_output_accuracy: 0.6536 - gender_output_loss: 0.6192 - loss: 28.2950 - val_age_output_loss: 257.9851 - val_age_output_mae: 12.8796 - val_gender_output_accuracy: 0.6800 - val_gender_output_loss: 0.5978 - val_loss: 252.8836
# Epoch 18/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - age_output_loss: 23.6200 - age_output_mae: 3.6703 - gender_output_accuracy: 0.6700 - gender_output_loss: 0.6006 - loss: 24.2206 - val_age_output_loss: 156.9544 - val_age_output_mae: 9.7486 - val_gender_output_accuracy: 0.6850 - val_gender_output_loss: 0.5917 - val_loss: 152.9744
# Epoch 19/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - age_output_loss: 26.8690 - age_output_mae: 3.8350 - gender_output_accuracy: 0.6786 - gender_output_loss: 0.6151 - loss: 27.4841 - val_age_output_loss: 266.9343 - val_age_output_mae: 13.2538 - val_gender_output_accuracy: 0.6650 - val_gender_output_loss: 0.6085 - val_loss: 264.0552
# Epoch 20/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - age_output_loss: 24.2933 - age_output_mae: 3.5693 - gender_output_accuracy: 0.6549 - gender_output_loss: 0.6117 - loss: 24.9050 - val_age_output_loss: 132.5572 - val_age_output_mae: 8.8510 - val_gender_output_accuracy: 0.6690 - val_gender_output_loss: 0.5951 - val_loss: 130.5350
# Epoch 21/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - age_output_loss: 24.0523 - age_output_mae: 3.6658 - gender_output_accuracy: 0.6683 - gender_output_loss: 0.6069 - loss: 24.6593 - val_age_output_loss: 223.1538 - val_age_output_mae: 12.0673 - val_gender_output_accuracy: 0.6820 - val_gender_output_loss: 0.5809 - val_loss: 218.5380
# Epoch 22/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - age_output_loss: 28.8608 - age_output_mae: 3.9569 - gender_output_accuracy: 0.6889 - gender_output_loss: 0.5875 - loss: 29.4483 - val_age_output_loss: 164.0493 - val_age_output_mae: 10.0306 - val_gender_output_accuracy: 0.7120 - val_gender_output_loss: 0.5638 - val_loss: 160.3347
# Epoch 23/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - age_output_loss: 21.2214 - age_output_mae: 3.3780 - gender_output_accuracy: 0.6844 - gender_output_loss: 0.5945 - loss: 21.8158 - val_age_output_loss: 121.0434 - val_age_output_mae: 8.1987 - val_gender_output_accuracy: 0.7000 - val_gender_output_loss: 0.5641 - val_loss: 118.9691
# Epoch 24/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 22.9892 - age_output_mae: 3.4994 - gender_output_accuracy: 0.6972 - gender_output_loss: 0.5806 - loss: 23.5698 - val_age_output_loss: 222.7167 - val_age_output_mae: 11.9972 - val_gender_output_accuracy: 0.6920 - val_gender_output_loss: 0.5679 - val_loss: 218.9646
# Epoch 25/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - age_output_loss: 22.6905 - age_output_mae: 3.4520 - gender_output_accuracy: 0.6811 - gender_output_loss: 0.5922 - loss: 23.2826 - val_age_output_loss: 113.1384 - val_age_output_mae: 8.1155 - val_gender_output_accuracy: 0.6860 - val_gender_output_loss: 0.5927 - val_loss: 111.3562
# Epoch 26/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - age_output_loss: 19.1270 - age_output_mae: 3.2133 - gender_output_accuracy: 0.6750 - gender_output_loss: 0.5898 - loss: 19.7168 - val_age_output_loss: 146.8090 - val_age_output_mae: 9.1105 - val_gender_output_accuracy: 0.6680 - val_gender_output_loss: 0.6107 - val_loss: 143.7716
# Epoch 27/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - age_output_loss: 19.7168 - age_output_mae: 3.3075 - gender_output_accuracy: 0.6861 - gender_output_loss: 0.5914 - loss: 20.3082 - val_age_output_loss: 138.3707 - val_age_output_mae: 9.3197 - val_gender_output_accuracy: 0.6930 - val_gender_output_loss: 0.5744 - val_loss: 136.1273
# Epoch 28/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 18.6113 - age_output_mae: 3.1672 - gender_output_accuracy: 0.6858 - gender_output_loss: 0.5861 - loss: 19.1974 - val_age_output_loss: 125.9885 - val_age_output_mae: 8.5519 - val_gender_output_accuracy: 0.6880 - val_gender_output_loss: 0.5674 - val_loss: 122.9797
# Epoch 29/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - age_output_loss: 18.3407 - age_output_mae: 3.1514 - gender_output_accuracy: 0.6884 - gender_output_loss: 0.5805 - loss: 18.9212 - val_age_output_loss: 113.9710 - val_age_output_mae: 8.0299 - val_gender_output_accuracy: 0.6890 - val_gender_output_loss: 0.5751 - val_loss: 111.1637
# Epoch 30/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - age_output_loss: 20.2489 - age_output_mae: 3.3067 - gender_output_accuracy: 0.6901 - gender_output_loss: 0.5802 - loss: 20.8291 - val_age_output_loss: 154.0568 - val_age_output_mae: 10.0020 - val_gender_output_accuracy: 0.6940 - val_gender_output_loss: 0.5581 - val_loss: 151.8168
# Epoch 31/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - age_output_loss: 17.8014 - age_output_mae: 3.0544 - gender_output_accuracy: 0.6758 - gender_output_loss: 0.5903 - loss: 18.3917 - val_age_output_loss: 91.5561 - val_age_output_mae: 6.8457 - val_gender_output_accuracy: 0.7170 - val_gender_output_loss: 0.5601 - val_loss: 89.3187
# Epoch 32/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 18.6117 - age_output_mae: 3.0996 - gender_output_accuracy: 0.6958 - gender_output_loss: 0.5687 - loss: 19.1805 - val_age_output_loss: 164.1907 - val_age_output_mae: 9.9606 - val_gender_output_accuracy: 0.6820 - val_gender_output_loss: 0.5739 - val_loss: 161.3524
# Epoch 33/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - age_output_loss: 18.2857 - age_output_mae: 3.1006 - gender_output_accuracy: 0.7037 - gender_output_loss: 0.5688 - loss: 18.8545 - val_age_output_loss: 92.6680 - val_age_output_mae: 7.2696 - val_gender_output_accuracy: 0.7100 - val_gender_output_loss: 0.5395 - val_loss: 90.6295
# Epoch 34/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - age_output_loss: 15.2175 - age_output_mae: 2.8191 - gender_output_accuracy: 0.7029 - gender_output_loss: 0.5636 - loss: 15.7812 - val_age_output_loss: 84.8439 - val_age_output_mae: 6.7922 - val_gender_output_accuracy: 0.6970 - val_gender_output_loss: 0.5492 - val_loss: 82.5758
# Epoch 35/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 15.2784 - age_output_mae: 2.8536 - gender_output_accuracy: 0.7012 - gender_output_loss: 0.5629 - loss: 15.8413 - val_age_output_loss: 97.1019 - val_age_output_mae: 7.4224 - val_gender_output_accuracy: 0.6930 - val_gender_output_loss: 0.5454 - val_loss: 95.9569
# Epoch 36/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - age_output_loss: 15.1694 - age_output_mae: 2.8576 - gender_output_accuracy: 0.7097 - gender_output_loss: 0.5635 - loss: 15.7329 - val_age_output_loss: 105.7788 - val_age_output_mae: 7.8226 - val_gender_output_accuracy: 0.7290 - val_gender_output_loss: 0.5170 - val_loss: 103.6309
# Epoch 37/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - age_output_loss: 15.8222 - age_output_mae: 2.8616 - gender_output_accuracy: 0.7188 - gender_output_loss: 0.5504 - loss: 16.3726 - val_age_output_loss: 89.9108 - val_age_output_mae: 7.1388 - val_gender_output_accuracy: 0.7220 - val_gender_output_loss: 0.5277 - val_loss: 88.0897
# Epoch 38/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - age_output_loss: 15.8457 - age_output_mae: 2.8707 - gender_output_accuracy: 0.6903 - gender_output_loss: 0.5732 - loss: 16.4190 - val_age_output_loss: 109.7124 - val_age_output_mae: 7.8594 - val_gender_output_accuracy: 0.7220 - val_gender_output_loss: 0.5282 - val_loss: 106.5854
# Epoch 39/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 14.7394 - age_output_mae: 2.7818 - gender_output_accuracy: 0.7149 - gender_output_loss: 0.5467 - loss: 15.2861 - val_age_output_loss: 87.8431 - val_age_output_mae: 6.9133 - val_gender_output_accuracy: 0.7310 - val_gender_output_loss: 0.5198 - val_loss: 85.6124
# Epoch 40/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - age_output_loss: 15.0026 - age_output_mae: 2.7964 - gender_output_accuracy: 0.7083 - gender_output_loss: 0.5521 - loss: 15.5547 - val_age_output_loss: 76.0505 - val_age_output_mae: 6.2533 - val_gender_output_accuracy: 0.7520 - val_gender_output_loss: 0.5215 - val_loss: 75.1282
# Epoch 41/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - age_output_loss: 14.8390 - age_output_mae: 2.7588 - gender_output_accuracy: 0.7314 - gender_output_loss: 0.5398 - loss: 15.3787 - val_age_output_loss: 82.1821 - val_age_output_mae: 6.6293 - val_gender_output_accuracy: 0.7420 - val_gender_output_loss: 0.5251 - val_loss: 80.4214
# Epoch 42/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 14.1011 - age_output_mae: 2.7851 - gender_output_accuracy: 0.7295 - gender_output_loss: 0.5416 - loss: 14.6427 - val_age_output_loss: 100.6116 - val_age_output_mae: 7.6142 - val_gender_output_accuracy: 0.7500 - val_gender_output_loss: 0.5231 - val_loss: 97.5638
# Epoch 43/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - age_output_loss: 15.4960 - age_output_mae: 2.8329 - gender_output_accuracy: 0.7229 - gender_output_loss: 0.5431 - loss: 16.0391 - val_age_output_loss: 104.6934 - val_age_output_mae: 7.6635 - val_gender_output_accuracy: 0.7340 - val_gender_output_loss: 0.5229 - val_loss: 102.1495
# Epoch 44/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - age_output_loss: 15.3485 - age_output_mae: 2.8322 - gender_output_accuracy: 0.7210 - gender_output_loss: 0.5419 - loss: 15.8904 - val_age_output_loss: 80.9088 - val_age_output_mae: 6.5801 - val_gender_output_accuracy: 0.7330 - val_gender_output_loss: 0.5275 - val_loss: 78.7850
# Epoch 45/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - age_output_loss: 13.7855 - age_output_mae: 2.6916 - gender_output_accuracy: 0.7230 - gender_output_loss: 0.5374 - loss: 14.3229 - val_age_output_loss: 84.1355 - val_age_output_mae: 6.6758 - val_gender_output_accuracy: 0.7360 - val_gender_output_loss: 0.5219 - val_loss: 81.4809
# Epoch 46/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - age_output_loss: 13.8213 - age_output_mae: 2.7303 - gender_output_accuracy: 0.7409 - gender_output_loss: 0.5214 - loss: 14.3428 - val_age_output_loss: 82.4005 - val_age_output_mae: 6.6765 - val_gender_output_accuracy: 0.7280 - val_gender_output_loss: 0.5125 - val_loss: 80.1481
# Epoch 47/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - age_output_loss: 13.1309 - age_output_mae: 2.6654 - gender_output_accuracy: 0.7386 - gender_output_loss: 0.5182 - loss: 13.6490 - val_age_output_loss: 75.5829 - val_age_output_mae: 6.2988 - val_gender_output_accuracy: 0.7420 - val_gender_output_loss: 0.4999 - val_loss: 74.3992
# Epoch 48/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - age_output_loss: 13.5943 - age_output_mae: 2.6832 - gender_output_accuracy: 0.7599 - gender_output_loss: 0.5120 - loss: 14.1063 - val_age_output_loss: 89.9491 - val_age_output_mae: 6.9914 - val_gender_output_accuracy: 0.7550 - val_gender_output_loss: 0.4899 - val_loss: 87.2663
# Epoch 49/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - age_output_loss: 14.4723 - age_output_mae: 2.7393 - gender_output_accuracy: 0.7443 - gender_output_loss: 0.5189 - loss: 14.9912 - val_age_output_loss: 80.7607 - val_age_output_mae: 6.7421 - val_gender_output_accuracy: 0.7220 - val_gender_output_loss: 0.5112 - val_loss: 79.5153
# Epoch 50/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - age_output_loss: 14.3408 - age_output_mae: 2.7326 - gender_output_accuracy: 0.7393 - gender_output_loss: 0.5214 - loss: 14.8623 - val_age_output_loss: 75.7473 - val_age_output_mae: 6.3028 - val_gender_output_accuracy: 0.7510 - val_gender_output_loss: 0.4870 - val_loss: 74.5773
# Epoch 51/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - age_output_loss: 13.1482 - age_output_mae: 2.5903 - gender_output_accuracy: 0.7461 - gender_output_loss: 0.5219 - loss: 13.6701 - val_age_output_loss: 75.9896 - val_age_output_mae: 6.4008 - val_gender_output_accuracy: 0.7600 - val_gender_output_loss: 0.4769 - val_loss: 75.0713
# Epoch 52/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - age_output_loss: 13.8423 - age_output_mae: 2.6711 - gender_output_accuracy: 0.7487 - gender_output_loss: 0.5123 - loss: 14.3547 - val_age_output_loss: 86.0697 - val_age_output_mae: 6.8733 - val_gender_output_accuracy: 0.7480 - val_gender_output_loss: 0.4877 - val_loss: 85.3071
# Epoch 53/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - age_output_loss: 14.3997 - age_output_mae: 2.7536 - gender_output_accuracy: 0.7279 - gender_output_loss: 0.5276 - loss: 14.9273 - val_age_output_loss: 85.3842 - val_age_output_mae: 6.8057 - val_gender_output_accuracy: 0.7560 - val_gender_output_loss: 0.4810 - val_loss: 84.2488
# Epoch 54/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - age_output_loss: 12.8185 - age_output_mae: 2.5733 - gender_output_accuracy: 0.7552 - gender_output_loss: 0.5003 - loss: 13.3189 - val_age_output_loss: 94.2793 - val_age_output_mae: 7.2634 - val_gender_output_accuracy: 0.7380 - val_gender_output_loss: 0.5000 - val_loss: 92.4817
# Epoch 55/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - age_output_loss: 13.0448 - age_output_mae: 2.6159 - gender_output_accuracy: 0.7593 - gender_output_loss: 0.4902 - loss: 13.5351 - val_age_output_loss: 94.6576 - val_age_output_mae: 7.3047 - val_gender_output_accuracy: 0.7540 - val_gender_output_loss: 0.4736 - val_loss: 92.8560
# Epoch 56/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - age_output_loss: 13.3973 - age_output_mae: 2.6097 - gender_output_accuracy: 0.7452 - gender_output_loss: 0.5052 - loss: 13.9024 - val_age_output_loss: 82.8459 - val_age_output_mae: 6.7632 - val_gender_output_accuracy: 0.7670 - val_gender_output_loss: 0.4637 - val_loss: 81.5282
# Epoch 57/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - age_output_loss: 13.5652 - age_output_mae: 2.6419 - gender_output_accuracy: 0.7705 - gender_output_loss: 0.4884 - loss: 14.0536 - val_age_output_loss: 82.1307 - val_age_output_mae: 6.7751 - val_gender_output_accuracy: 0.7530 - val_gender_output_loss: 0.4701 - val_loss: 80.9616
# Epoch 58/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - age_output_loss: 12.2168 - age_output_mae: 2.5057 - gender_output_accuracy: 0.7540 - gender_output_loss: 0.4992 - loss: 12.7160 - val_age_output_loss: 79.6449 - val_age_output_mae: 6.4773 - val_gender_output_accuracy: 0.7600 - val_gender_output_loss: 0.4620 - val_loss: 77.5987
# Epoch 59/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - age_output_loss: 13.5150 - age_output_mae: 2.6362 - gender_output_accuracy: 0.7725 - gender_output_loss: 0.4740 - loss: 13.9890 - val_age_output_loss: 87.3231 - val_age_output_mae: 6.8407 - val_gender_output_accuracy: 0.7650 - val_gender_output_loss: 0.4604 - val_loss: 85.6665
# Epoch 60/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - age_output_loss: 11.2678 - age_output_mae: 2.4601 - gender_output_accuracy: 0.7740 - gender_output_loss: 0.4735 - loss: 11.7413 - val_age_output_loss: 78.5336 - val_age_output_mae: 6.4314 - val_gender_output_accuracy: 0.7540 - val_gender_output_loss: 0.4653 - val_loss: 77.0552
# Epoch 61/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - age_output_loss: 12.7061 - age_output_mae: 2.5535 - gender_output_accuracy: 0.7789 - gender_output_loss: 0.4708 - loss: 13.1769 - val_age_output_loss: 92.3473 - val_age_output_mae: 7.0575 - val_gender_output_accuracy: 0.7700 - val_gender_output_loss: 0.4482 - val_loss: 90.2178
# Epoch 62/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - age_output_loss: 13.4212 - age_output_mae: 2.6596 - gender_output_accuracy: 0.7738 - gender_output_loss: 0.4768 - loss: 13.8979 - val_age_output_loss: 95.3021 - val_age_output_mae: 7.3327 - val_gender_output_accuracy: 0.7760 - val_gender_output_loss: 0.4457 - val_loss: 93.3253

# %% [markdown]
# ## STEP4B: Draw the learning curves
# Draw four learning curve figures for model B as follows.
# 1. The loss of the gender classification over the training and validation set
# 2. The accuracy of the gender classification over the training and validation set
# 3. The loss of the age estimation over the training and validation set
# 4. The MAE of the age estimation over the training and validation set

# %%
#
# Gender Classification Training and Validation Loss

plt.figure(figsize=(10,6))
plt.plot(history.history['gender_output_loss'], label='Training Loss')
plt.plot(history.history['val_gender_output_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.title('Gender Classification Training and Validation Loss')
plt.grid(True)
plt.ylim([0,1.0])
plt.legend()
plt.show()

# Gender Classification Training and Validation Accuracy

plt.figure(figsize=(10,6))
plt.plot(history.history['gender_output_accuracy'], label='Training Accuracy')
plt.plot(history.history['val_gender_output_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.title('Gender Classification Training and Validation Accuracy')
plt.grid(True)
plt.ylim([0,1.0])
plt.legend()
plt.show()

# Age Estimation Training and Validation Loss

plt.figure(figsize=(10,6))
plt.plot(history.history['age_output_loss'], label='Training Loss')
plt.plot(history.history['val_age_output_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.title('Age Estimation Training and Validation Loss')
plt.grid(True)
plt.legend()
plt.show()

# Age Estimation Training and Validation MAE

plt.figure(figsize=(10,6))
plt.plot(history.history['age_output_mae'], label='Mean Absolute Error (MAE) of Training Set')
plt.plot(history.history['val_age_output_mae'], label='Mean Absolute Error (MAE) of Validation Set')
plt.xlabel('Epoch')
plt.title('MAE of Age Estimation for Training and Validation Sets')
plt.grid(True)
plt.legend()
plt.show()
#

# %% [markdown]
# ## STEP5: Evaluate the model on the test set
# I will load your two models for testing. The test set will not be available before your submission.
#
# The metrics for measuring the performance on the test set are:
# - age estimation: MAE (Mean Absolute Error)
# - gender classification: accuracy

# %%
#
# Don't add code in this cell when submitting this file
#
